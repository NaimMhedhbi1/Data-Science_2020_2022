# %%
import numpy as np
import pandas as pd
import os
import sys
from google.colab import drive
import matplotlib.pyplot as plt
import math
import itertools

import random
import seaborn as sns

# %%
#mount google colab
drive.mount('/content/drive',force_remount = True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Topic:
# What does the musician(artists) social network look like?
# - Firstly, how will we measure individual artists' influence? We use followers number in
# the data set (influence_data)
# - Then, we calculate and average the influence of each song of individual artists, and
# incorporate the song influence with the followers number together as the general
# influence of artists

# %%
df_inf = pd.read_csv('/content/drive/MyDrive/Richard_FRL/Project Data/2021_ICM_Problem_D_Data/influence_data.csv')
df_full= pd.read_csv('/content/drive/MyDrive/Richard_FRL/Project Data/2021_ICM_Problem_D_Data/full_music_data.csv')

# %%
df_full['artists_id'] = df_full['artists_id'].apply(lambda x: x.replace('[','').replace(']',''))
df_full['artist_names'] = df_full['artist_names'].apply(lambda x: x.replace('[','').replace(']',''))
df_full['artist_names'] = df_full['artist_names'].apply(lambda x: x.replace('"',''))
df_full['artist_names'] = df_full['artist_names'].apply(lambda x: x.replace("'",""))
#df_full['artists_id'] = df_full['artists_id'].apply(lambda x: x.replace(', ',''))

#remove brackets from the column 
df_full['artists_id'] = df_full['artists_id'].astype(str)

# %%
df_full['artists_id']
# Out:
# 0        178301
# 1        178301
# 2        178301
# 3        625201
# 4        625201
#           ...
# 98335    690254
# 98336    690254
# 98337    690254
# 98338    690254
# 98339    690254
# Name: artists_id, Length: 98340, dtype: object

# %%
df_full['length'] = df_full.artists_id.str.len()
df_full = df_full[df_full.length <= 7]

# %%
df_full['artists_id'].value_counts()
# Out:
# 26350     874
# 79016     684
# 792507    677
# 119107    610
# 66915     539
#          ...
# 861057      1
# 238297      1
# 36537       1
# 817000      1
# 239638      1
# Name: artists_id, Length: 5549, dtype: int64

# %%
df_full['artists_id'] = df_full['artists_id'].astype(int)

# %%
#remove brackets from the column 
df_full['artist_names'].value_counts()
# Out:
# Wolfgang Amadeus Mozart    874
# Billie Holiday             684
# Frank Sinatra              677
# Vladimir Horowitz          610
# Bob Dylan                  539
#                           ...
# The KLF                      1
# Johnny Guarnieri             1
# Danny & the Juniors          1
# Shed Seven                   1
# Elle Varner                  1
# Name: artist_names, Length: 5549, dtype: int64

# %%
df_inf['followers_count'] = df_inf.groupby('influencer_id').influencer_id.transform('count')
df_inf
# Out:
#        influencer_id  influencer_name  ... follower_active_start  followers_count
# 0             759491    The Exploited  ...                  1980               12
# 1              25462           Tricky  ...                  1990               12
# 2              66915        Bob Dylan  ...                  1990              389
# 3              71209    Leonard Cohen  ...                  1990               64
# 4              91438     The Gun Club  ...                  1990                9
# ...              ...              ...  ...                   ...              ...
# 42765         580300   Sufjan Stevens  ...                  2010                3
# 42766         261309      Vybz Kartel  ...                  2010                1
# 42767         467203  Michael Jackson  ...                  2010              101
# 42768        2518003          Popcaan  ...                  2010                1
# 42769        2896351        Tommy Lee  ...                  2010                1
#
# [42770 rows x 9 columns]

# %%
"""df_inf.to_csv('df_inf.csv')
# !cp df_inf.csv '/content/drive/MyDrive/Richard_FRL/Project Data/2021_ICM_Problem_D_Data/'"""
# Out:
# "df_inf.to_csv('df_inf.csv')\n!cp df_inf.csv '/content/drive/MyDrive/Richard_FRL/Project Data/2021_ICM_Problem_D_Data/'"

# %%
df_full['song_inf'] = df_full.groupby(['artists_id','song_title (censored)'])['popularity'].transform('mean') 
df_full['song_inf_avg'] = df_full.groupby(['artists_id'])['song_inf'].transform('mean')

# %%
df_full
# Out:
#            artist_names  artists_id  ...  song_inf  song_inf_avg
# 0      Fat Freddys Drop      178301  ...      54.0     54.000000
# 1      Fat Freddys Drop      178301  ...      53.0     54.000000
# 2      Fat Freddys Drop      178301  ...      55.0     54.000000
# 3       Alexander ONeal      625201  ...      34.0     39.600000
# 4       Alexander ONeal      625201  ...      37.0     39.600000
# ...                 ...         ...  ...       ...           ...
# 98335            ZZ Top      690254  ...      33.0     39.766355
# 98336            ZZ Top      690254  ...      32.0     39.766355
# 98337            ZZ Top      690254  ...      31.0     39.766355
# 98338            ZZ Top      690254  ...      58.0     39.766355
# 98339            ZZ Top      690254  ...      44.5     39.766355
#
# [93930 rows x 22 columns]

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93930 entries, 0 to 98339
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   artist_names           93930 non-null  object
#  1   artists_id             93930 non-null  int64
#  2   danceability           93930 non-null  float64
#  3   energy                 93930 non-null  float64
#  4   valence                93930 non-null  float64
#  5   tempo                  93930 non-null  float64
#  6   loudness               93930 non-null  float64
#  7   mode                   93930 non-null  int64
#  8   key                    93930 non-null  int64
#  9   acousticness           93930 non-null  float64
#  10  instrumentalness       93930 non-null  float64
#  11  liveness               93930 non-null  float64
#  12  speechiness            93930 non-null  float64
#  13  explicit               93930 non-null  int64
#  14  duration_ms            93930 non-null  int64
#  15  popularity             93930 non-null  int64
#  16  year                   93930 non-null  int64
#  17  release_date           93930 non-null  object
#  18  song_title (censored)  93930 non-null  object
#  19  length                 93930 non-null  int64
#  20  song_inf               93930 non-null  float64
#  21  song_inf_avg           93930 non-null  float64
# dtypes: float64(11), int64(8), object(3)
# memory usage: 16.5+ MB

# %%
df_inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42770 entries, 0 to 42769
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   influencer_id            42770 non-null  int64
#  1   influencer_name          42770 non-null  object
#  2   influencer_main_genre    42770 non-null  object
#  3   influencer_active_start  42770 non-null  int64
#  4   follower_id              42770 non-null  int64
#  5   follower_name            42770 non-null  object
#  6   follower_main_genre      42770 non-null  object
#  7   follower_active_start    42770 non-null  int64
#  8   followers_count          42770 non-null  int64
# dtypes: int64(5), object(4)
# memory usage: 2.9+ MB

# %%
df_inf.rename(columns = {'influencer_id':'artists_id','influencer_name':'artist_names'}, inplace = True)

# %%
df_inf['artists_id'] = df_inf['artists_id'].astype(int)

# %%
A = df_inf['artists_id']
B = df_full['artists_id']
len(list(set(A) & set(B)))
# Out:
# 3600

# %%
df_inf['artist_names'].value_counts()
# Out:
# The Beatles           615
# Bob Dylan             389
# The Rolling Stones    319
# David Bowie           238
# Led Zeppelin          221
#                      ...
# Elisa                   1
# Zedd                    1
# Jeff Lorber             1
# Ed Ames                 1
# Peter Sarstedt          1
# Name: artist_names, Length: 3761, dtype: int64

# %%
df_full_m = df_full[['song_inf_avg','artist_names','artists_id']]
df_inf_m = df_inf[['followers_count','artist_names','artists_id']]

# %%
df_full_m
# Out:
#        song_inf_avg      artist_names  artists_id
# 0         54.000000  Fat Freddys Drop      178301
# 1         54.000000  Fat Freddys Drop      178301
# 2         54.000000  Fat Freddys Drop      178301
# 3         39.600000   Alexander ONeal      625201
# 4         39.600000   Alexander ONeal      625201
# ...             ...               ...         ...
# 98335     39.766355            ZZ Top      690254
# 98336     39.766355            ZZ Top      690254
# 98337     39.766355            ZZ Top      690254
# 98338     39.766355            ZZ Top      690254
# 98339     39.766355            ZZ Top      690254
#
# [93930 rows x 3 columns]

# %%
df_inf_m
# Out:
#        followers_count     artist_names  artists_id
# 0                   12    The Exploited      759491
# 1                   12           Tricky       25462
# 2                  389        Bob Dylan       66915
# 3                   64    Leonard Cohen       71209
# 4                    9     The Gun Club       91438
# ...                ...              ...         ...
# 42765                3   Sufjan Stevens      580300
# 42766                1      Vybz Kartel      261309
# 42767              101  Michael Jackson      467203
# 42768                1          Popcaan     2518003
# 42769                1        Tommy Lee     2896351
#
# [42770 rows x 3 columns]

# %%
df_j = pd.merge(df_inf_m,df_full_m, how='inner',on=['artists_id']).drop_duplicates()
df_j
# Out:
#          followers_count artist_names_x  ...  song_inf_avg  artist_names_y
# 0                     12  The Exploited  ...     31.714286   The Exploited
# 84                    12         Tricky  ...     46.666667          Tricky
# 156                  389      Bob Dylan  ...     30.849722       Bob Dylan
# 209827                64  Leonard Cohen  ...     41.835616   Leonard Cohen
# 214499                 9   The Gun Club  ...     30.833333    The Gun Club
# ...                  ...            ...  ...           ...             ...
# 3216147                1     Thom Yorke  ...     52.666667      Thom Yorke
# 3216150                1     King Krule  ...     51.750000      King Krule
# 3216154                1    Vybz Kartel  ...     62.000000     Vybz Kartel
# 3216155                1        Popcaan  ...     54.000000         Popcaan
# 3216157                1      Tommy Lee  ...     40.000000       Tommy Lee
#
# [3603 rows x 5 columns]

# %%
"""df_j.to_csv('df_j.csv')
# !cp df_j.csv '/content/drive/MyDrive/Richard_FRL/Project Data/2021_ICM_Problem_D_Data/'"""
# Out:
# "df_j.to_csv('df_j.csv')\n!cp df_j.csv '/content/drive/MyDrive/Richard_FRL/Project Data/2021_ICM_Problem_D_Data/'"

# %%
df_j['total_influence'] = df_j['followers_count'] + df_j['song_inf_avg']

# %%
df_infc = df_j[['artists_id','total_influence']]
df_infc
# Out:
#          artists_id  total_influence
# 0            759491        43.714286
# 84            25462        58.666667
# 156           66915       419.849722
# 209827        71209       105.835616
# 214499        91438        39.833333
# ...             ...              ...
# 3216147      588887        53.666667
# 3216150     2814183        52.750000
# 3216154      261309        63.000000
# 3216155     2518003        55.000000
# 3216157     2896351        41.000000
#
# [3603 rows x 2 columns]

# %% [markdown]
# # Using that, we can calculate influence by implementing a breadth-first search algorithm (BFS) and rank artists based on score.

# %%
df_inf
# Out:
#        artists_id     artist_names  ... follower_active_start  followers_count
# 0          759491    The Exploited  ...                  1980               12
# 1           25462           Tricky  ...                  1990               12
# 2           66915        Bob Dylan  ...                  1990              389
# 3           71209    Leonard Cohen  ...                  1990               64
# 4           91438     The Gun Club  ...                  1990                9
# ...           ...              ...  ...                   ...              ...
# 42765      580300   Sufjan Stevens  ...                  2010                3
# 42766      261309      Vybz Kartel  ...                  2010                1
# 42767      467203  Michael Jackson  ...                  2010              101
# 42768     2518003          Popcaan  ...                  2010                1
# 42769     2896351        Tommy Lee  ...                  2010                1
#
# [42770 rows x 9 columns]

# %%
df_inf['follower_name'] = df_inf['follower_name'].astype(str)
df_inf['artist_names'] = df_inf['artist_names'].astype(str)

# %%
data= df_inf.groupby('artist_names')['follower_name'].apply(lambda x: x.tolist()).to_dict()
#Out[8]: {89989: [32598, 3085083], 95281: [3085083]}
data
# Out:
# {"'Til Tuesday": ['Gossip',
#   'The Cardigans',
#   'Beth Orton',
#   'The Postal Service'],
#  '*NSYNC': ["Colby O'Donis",
#   'Girls Aloud',
#   'Jonas Brothers',
#   'Dream',
#   'Jesse McCartney',
#   'Aaron Carter',
#   'The Lonely Island',
#   'One Direction',
#   'Sports'],
#  '10,000 Maniacs': ['Sixpence None the Richer',
#   'The Innocence Mission',
#   'The Corrs',
#   'Ivy',
#   'Dido',
#   'Joss Stone',
#   'Lisa Loeb',
#   'Jewel',
#   'The Cardigans',
#   'The Cranberries',
#   'Veruca Salt',
#   'Sarah McLachlan',
#   'KT Tunstall',
#   'Alanis Morissette'],
#  '10cc': ['Sherbet',
#   'Amy Grant',
#   'The Beautiful South',
#   'The Blue Nile',
#   'City Boy',
#   'Pulp',
#   'Julian Cope',
#   'Jellyfish',
#   'Oingo Boingo',
#   'Of Montreal',
#   'They Might Be Giants',
#   'XTC',
#   'Squeeze',
#   'Peter Gabriel',
#   'The Art of Noise'],
#  '112': ['Chris Brown',
#   'Pretty Ricky',
#   'Lloyd',
#   'Day26',
#   'Cupid',
#   'Adrian Marcel',
#   'Bando Jonez'],
#  '1910 Fruitgum Company': ['Teenage Fanclub',
#   'Ramones',
#   'Britney Spears',
#   'Tiffany',
#   'Hanson'],
#  '20/20': ['Fastball',
#   'Jon Brion',
#   'Matthew Sweet',
#   'Aimee Mann',
#   'Gin Blossoms'],
#  '3 Doors Down': ['10 Years', 'Daughtry', 'Hinder'],
#  '311': ['P.O.D.',
#   'Papa Roach',
#   'Skindred',
#   'The Ataris',
#   'Soulfly',
#   'Insane Clown Posse',
#   'Kid Rock',
#   'Kottonmouth Kings',
#   'Disturbed',
#   'Uncle Kracker',
#   'Saliva',
#   'Linkin Park',
#   'Methods of Mayhem',
#   'Sugar Ray',
#   'Lit',
#   '(hed) p.e.'],
#  '4 Non Blondes': ['P!nk'],
#  '54-40': ['Hootie & the Blowfish'],
#  '7 Seconds': ['Smoking Popes',
#   'Face to Face',
#   'Green Day',
#   'Rise Against',
#   'Pennywise',
#   'Dillinger Four',
#   'Screeching Weasel',
#   'NOFX',
#   'Chiodos',
#   'AFI',
#   'The Bouncing Souls',
#   'Strike Anywhere',
#   'Yellowcard',
#   'Dropkick Murphys',
#   'Jimmy Eat World',
#   'Anti-Flag'],
#  '808 State': ["Stereo MC's",
#   'Amon Tobin',
#   'Soul Coughing',
#   'The Chemical Brothers',
#   'Black Grape',
#   'Lamb',
#   'Fatboy Slim',
#   'Portishead',
#   'Utah Saints',
#   'Jesus Jones',
#   'Propellerheads',
#   'The Prodigy',
#   'Aphex Twin',
#   'Basshunter',
#   'Seal',
#   'BjÃ¶rk',
#   'Ladytron',
#   'Underworld',
#   'Death in Vegas',
#   'The Orb',
#   'The Sugarcubes',
#   'Manic Street Preachers'],
#  '999': ['The Exploited', 'The Vandals'],
#  '? & the Mysterians': ['Steppenwolf',
#   'Bob Seger',
#   'The Hives',
#   'Inspiral Carpets',
#   'Garland Jeffreys',
#   'Eddie & the Hot Rods',
#   'Los Lobos',
#   'Texas Tornados',
#   'Suicide',
#   'Mudhoney',
#   'Bruce Springsteen',
#   'The Stranglers',
#   'The Vines',
#   'The Horrors',
#   'Iron Butterfly',
#   'Lyres',
#   'Rodriguez'],
#  'A Certain Ratio': ['The Housemartins',
#   'Primal Scream',
#   'Klaxons',
#   'The Rapture',
#   'Happy Mondays',
#   'The Stone Roses',
#   'LCD Soundsystem',
#   'Santigold'],
#  'A Flock of Seagulls': ['The Faint',
#   'Interpol',
#   'Fischerspooner',
#   'Hot Chip',
#   'MaxÃ¯mo Park',
#   'Blue October',
#   'Barcelona',
#   'Scissor Sisters',
#   'The Postal Service'],
#  'A Guy Called Gerald': ['Squarepusher',
#   'Portishead',
#   'Jesus Jones',
#   'Seal',
#   'Death in Vegas'],
#  'A Perfect Circle': ['Red Sun Rising'],
#  'A*Teens': ['Big Time Rush'],
#  'A.C. Reed': ['Bonnie Raitt'],
#  'A.R. Kane': ['Morcheeba', 'The Veldt', 'Fever Ray', 'Phantogram'],
#  'ABBA': ['Anastacia',
#   'B*Witched',
#   'The Cover Girls',
#   'ExposÃ©',
#   'Erasure',
#   'Madonna',
#   'Wham!',
#   'S Club 7',
#   'Robyn',
#   'Sarah Brightman',
#   'Roxette',
#   'Prefab Sprout',
#   'a-ha',
#   'Ace of Base',
#   'ABC',
#   'Eros Ramazzotti',
#   'Gloria Estefan',
#   'Steps',
#   'Kylie Minogue',
#   'Bananarama',
#   'Falco',
#   'Los del Rio',
#   'Wilson Phillips',
#   'Lykke Li',
#   'A*Teens',
#   'MisterWives'],
#  'ABC': ['Paul Young',
#   'M People',
#   'Howard Jones',
#   'Deee-Lite',
#   'Pet Shop Boys',
#   'Phoenix',
#   'Roger Sanchez',
#   'Pulp',
#   'Rick Astley',
#   'a-ha',
#   'George Michael',
#   'Happy Mondays',
#   'Scissor Sisters'],
#  'AC/DC': ['Soundgarden',
#   'Alice in Chains',
#   'Tenacious D',
#   'Skid Row',
#   'Tesla',
#   'Smoking Popes',
#   'Audioslave',
#   'Andrew W.K.',
#   'Silverchair',
#   'The Black Crowes',
#   'The Angels',
#   'Babylon A.D.',
#   'Babes in Toyland',
#   'The Living End',
#   'Wolfmother',
#   'Bracket',
#   'Iron Maiden',
#   'Kix',
#   'L7',
#   'Krokus',
#   'Crowbar',
#   'Jackyl',
#   'The Cult',
#   'The Darkness',
#   'Twisted Sister',
#   'Foo Fighters',
#   'Def Leppard',
#   'Warrant',
#   'Drive-By Truckers',
#   'Dead Moon',
#   'Saxon',
#   'Van Halen',
#   'Urge Overkill',
#   'Venom',
#   'Jet',
#   'Poison',
#   'Nirvana',
#   'Queens of the Stone Age',
#   'Metallica',
#   'Red House Painters',
#   'The Witnesses',
#   'Buckcherry',
#   'Hellyeah',
#   "Guns N' Roses",
#   'Jason Isbell',
#   'The Subways',
#   'Britny Fox',
#   'Zakk Wylde',
#   'Shellac',
#   'The All-American Rejects',
#   'Big Black',
#   'L.A. Guns',
#   'The Donnas',
#   'Great White',
#   'Dropkick Murphys',
#   'Veruca Salt',
#   'Turbonegro',
#   'Velvet Revolver',
#   'Quiet Riot',
#   'The Mighty Mighty Bosstones',
#   'The White Stripes',
#   'Accept',
#   'Thunder',
#   'Fu Manchu',
#   'Alabama Shakes'],
#  'AFI': ['Hawthorne Heights',
#   'Taking Back Sunday',
#   'The Academy Is...',
#   'Panic! At the Disco',
#   'My Chemical Romance',
#   'Thursday',
#   'Avenged Sevenfold',
#   'Motionless in White',
#   'From First to Last',
#   'The Fall of Troy',
#   'Escape the Fate',
#   'The White Tie Affair',
#   'Black Veil Brides',
#   'Andy Black'],
#  'ATB': ['Cash Cash'],
#  'Aaliyah': ['Keyshia Cole',
#   'Christina Milian',
#   'Cassie',
#   "Destiny's Child",
#   'Ciara',
#   "Lil' Mo",
#   'JoJo',
#   'Lumidee',
#   'Nivea',
#   '3LW',
#   'Adina Howard',
#   'Britney Spears',
#   'Allure',
#   'Blaque',
#   'BeyoncÃ©',
#   'Cherish',
#   'Christina Aguilera',
#   'Dream',
#   'Sugababes',
#   'Ashanti',
#   'Kristinia DeBarge',
#   'Tink',
#   'The Weeknd',
#   'Zendaya',
#   'JhenÃ© Aiko',
#   'Kehlani',
#   'Tinashe'],
#  'Aaron Carter': ['Big Time Rush'],
#  'Aaron Neville': ['Billy Joe Royal',
#   'Boyz II Men',
#   'Johnny Adams',
#   'Amos Lee',
#   'Chris Isaak',
#   'Norah Jones'],
#  'Aaron Tippin': ['Little Big Town',
#   'Sugarland',
#   'Brad Paisley',
#   'Joe Nichols',
#   'Dierks Bentley',
#   'Rascal Flatts'],
#  'Abbey Lincoln': ['Erykah Badu',
#   'Cassandra Wilson',
#   'Dianne Reeves',
#   'Diana Krall',
#   'Mary Wells',
#   'Anita Baker',
#   'Jane Monheit'],
#  'Accept': ['Sodom',
#   'Soilwork',
#   'Celtic Frost',
#   'Running Wild',
#   'Rage',
#   'Annihilator',
#   '3 Inches of Blood',
#   'Helloween'],
#  'Ace': ['Dire Straits', 'Rockpile', 'The Boomtown Rats'],
#  'Ace Frehley': ['Tesla', 'Faster Pussycat', 'Jerry Cantrell', 'Nirvana'],
#  'Ace of Base': ['Spice Girls',
#   'Tegan and Sara',
#   'Anastacia',
#   'Boyzone',
#   'Beck',
#   'S Club 7',
#   'Robyn',
#   '*NSYNC',
#   'Atomic Kitten',
#   'Britney Spears',
#   'Yeasayer',
#   'Cascada',
#   'Backstreet Boys',
#   'Katy Perry',
#   'Lady Gaga',
#   'Twin Shadow',
#   'A*Teens'],
#  'Acker Bilk': ['Herb Alpert'],
#  'Adam Ant': ['Bow Wow Wow',
#   'Culture Club',
#   'Gene Loves Jezebel',
#   'No Doubt',
#   'Elastica',
#   'Black Kids',
#   'FKA twigs',
#   'Andy Black'],
#  'Adam Sandler': ['Mike Birbiglia', 'Dane Cook'],
#  'Adamski': ['Seal'],
#  'Adele': ['Ellie Goulding', 'Sam Smith', 'Izzy Bizu'],
#  'Adina Howard': ['K. Michelle'],
#  'Admiral Bailey': ['Shabba Ranks', 'Buju Banton'],
#  'Adolescents': ['NOFX', 'Mudhoney', 'blink-182'],
#  'Adriano Celentano': ['Zucchero'],
#  'Aerosmith': ['Soundgarden',
#   'Pantera',
#   'Spinal Tap',
#   'Slaughter',
#   'Slash',
#   'Skid Row',
#   'Shinedown',
#   'Trixter',
#   'Tesla',
#   'Pearl Jam',
#   'Audioslave',
#   'The Black Crowes',
#   'Blind Melon',
#   'The Angels',
#   'Babylon A.D.',
#   'Bon Jovi',
#   'Boston',
#   'Billy Squier',
#   'Kid Rock',
#   'Kix',
#   'Jackyl',
#   'Korn',
#   'Cinderella',
#   'The Cult',
#   'The Darkness',
#   'Twisted Sister',
#   'Europe',
#   'Faster Pussycat',
#   'Staind',
#   'Def Leppard',
#   'David Lee Roth',
#   'Van Halen',
#   'Saigon Kick',
#   'Lita Ford',
#   'QueensrÃ¿che',
#   'Ratt',
#   'Poison',
#   'Nirvana',
#   'Queens of the Stone Age',
#   'The Replacements',
#   'Metallica',
#   'The Runaways',
#   'Monster Magnet',
#   'MÃ¶tley CrÃ¼e',
#   'Mother Love Bone',
#   'Buckcherry',
#   "Guns N' Roses",
#   'Saving Abel',
#   'Britny Fox',
#   'Stone Temple Pilots',
#   'Godsmack',
#   'Testament',
#   'L.A. Guns',
#   'Extreme',
#   'Great White',
#   'Vince Neil',
#   'W.A.S.P.',
#   'Loverboy',
#   'Velvet Revolver',
#   'Quiet Riot',
#   'The Mighty Mighty Bosstones',
#   'Thunder',
#   'Hanoi Rocks',
#   'Asking Alexandria',
#   'Black Veil Brides',
#   'Andy Black',
#   'Mika'],
#  'Agent Orange': ['Slightly Stoopid',
#   'Green Day',
#   'Pennywise',
#   'The Offspring',
#   'blink-182'],
#  'Agnostic Front': ['Sick of It All',
#   'Soulfly',
#   'Biohazard',
#   'Unearth',
#   'Rise Against',
#   'Unsane',
#   'Vision of Disorder',
#   'Rancid',
#   'Chiodos',
#   'Hatebreed',
#   'H2O',
#   'Lamb of God',
#   'Cro-Mags',
#   'Dropkick Murphys',
#   'Gorilla Biscuits'],
#  'Ahmad Jamal': ['Bob James',
#   'Keith Jarrett',
#   'Jack DeJohnette',
#   'Chick Corea',
#   'Les McCann',
#   'Ramsey Lewis',
#   'Miles Davis',
#   'George Duke',
#   'Monty Alexander',
#   'Marcus Roberts',
#   'Wynton Kelly',
#   'Gary Burton',
#   'Bill Charlap',
#   'Bobby McFerrin',
#   'Gene Harris',
#   'Horace Parlan',
#   'Red Garland',
#   'Herbie Hancock',
#   'Robert Glasper Experiment'],
#  'Aimee Mann': ['Kings of Convenience',
#   'Fiona Apple',
#   'Rilo Kiley',
#   'Dido',
#   'Jason Mraz',
#   'Joseph Arthur',
#   'Liz Phair',
#   'Sara Bareilles',
#   'Matt Nathanson',
#   'Regina Spektor',
#   'The Weepies',
#   'Michael Penn',
#   'Vanessa Carlton',
#   'Alanis Morissette',
#   'Laura Marling',
#   'Carly Rae Jepsen'],
#  'Air': ['Simian',
#   'Kings of Convenience',
#   'Bonobo',
#   'Lemon Jelly',
#   'Justice',
#   'Zero 7',
#   'TÃ©lÃ©popmusik',
#   'Sia',
#   'SÃ©bastien Tellier',
#   'Broadcast',
#   'Black Moth Super Rainbow',
#   'STRFKR',
#   'Washed Out'],
#  'Air Supply': ['Clay Aiken',
#   'CÃ©line Dion',
#   'Josh Groban',
#   'Donna Lewis',
#   'Mr. Mister',
#   'Savage Garden',
#   'Merril Bainbridge'],
#  'Akon': ['Verse Simmonds', 'Jonn Hart'],
#  'Al B. Sure!': ['Tevin Campbell',
#   'Silk',
#   'Jodeci',
#   'Dru Hill',
#   'T-Pain',
#   'Mario',
#   'Usher',
#   'Justin Timberlake',
#   'J. Holiday',
#   'Ginuwine',
#   'Lloyd',
#   'Musiq Soulchild',
#   '112',
#   'Eric Bellinger'],
#  'Al Bowlly': ['Ben E. King', 'Frank Sinatra'],
#  'Al Cohn': ['Zoot Sims', 'Quincy Jones', 'Stan Getz', 'The Lounge Lizards'],
#  'Al Di Meola': ['Steve Vai', 'Jesse Cook', 'Joe Satriani'],
#  'Al Green': ["Terence Trent D'Arby",
#   'Teddy Pendergrass',
#   'Shelby Lynne',
#   'The Beautiful South',
#   'Peabo Bryson',
#   'Susan Tedeschi',
#   'Steve Winwood',
#   'Babyface',
#   'Bill Withers',
#   'Kenny Lattimore',
#   'Kirk Franklin',
#   'Billy Joe Royal',
#   'Boyz II Men',
#   'Joe',
#   'Ledisi',
#   'Craig David',
#   'Jai Uttal',
#   'Talking Heads',
#   "D'Angelo",
#   'James Ingram',
#   'Fred Hammond',
#   'BeBe & CeCe Winans',
#   'Eva Cassidy',
#   'Jamiroquai',
#   'UB40',
#   'Eurythmics',
#   'Luther Vandross',
#   'Macy Gray',
#   'Robin Thicke',
#   'Jeff Buckley',
#   'Lionel Richie',
#   'Hootie & the Blowfish',
#   'Mario',
#   'Howard Hewett',
#   'Josh Rouse',
#   'Sade',
#   'Maroon 5',
#   'Robert Randolph',
#   'Martin Sexton',
#   'Marvin Sease',
#   'Justin Timberlake',
#   'Jermaine Jackson',
#   'Ruben Studdard',
#   'Prince',
#   'Raphael Saadiq',
#   'The Subdudes',
#   'The Sea and Cake',
#   'Brian McKnight',
#   'David Bowie',
#   'Anita Baker',
#   'Seal',
#   'Anthony Hamilton',
#   'Aaron Neville',
#   'Annie Lennox',
#   'Al B. Sure!',
#   'Daryl Hall & John Oates',
#   'Hezekiah Walker',
#   'Lyfe Jennings',
#   'Marc Broussard',
#   'Dave Hollister',
#   'Keith Sweat',
#   'Leela James',
#   'Dwight Yoakam',
#   'Eric BenÃ©t',
#   'John Legend',
#   'Robert Cray',
#   'Ne-Yo',
#   'Marshall Crenshaw',
#   'Maxwell',
#   'Gnarls Barkley',
#   'Montell Jordan',
#   'Musiq Soulchild',
#   'Will Downing',
#   'Sharon Jones',
#   'Brett Young',
#   'Kevin Lyttle',
#   'Nick Hakim',
#   'HONNE'],
#  'Al Jarreau': ['Kem', 'Tuck & Patti', 'Toni Braxton'],
#  'Al Kooper': ['Shuggie Otis'],
#  'Al Martino': ['Engelbert Humperdinck'],
#  'Al Stewart': ['Lambchop', 'Elliott Smith', 'Devendra Banhart', 'Cat Power'],
#  'Alabama': ['Trick Pony',
#   'Shenandoah',
#   'The Lost Trailers',
#   'Billy Ray Cyrus',
#   'Confederate Railroad',
#   'Emerson Drive',
#   'Ricochet',
#   'Diamond Rio',
#   'Little Big Town',
#   'Little Texas',
#   'Lonestar',
#   'Jason Aldean',
#   'McBride & the Ride',
#   'Restless Heart',
#   'Nickel Creek',
#   'Luke Bryan',
#   'Toby Keith',
#   'Brooks & Dunn',
#   'Daryle Singletary',
#   'Tim McGraw',
#   'Jamey Johnson',
#   'Highway 101',
#   'Big & Rich',
#   'Garth Brooks',
#   'John Michael Montgomery',
#   'Sawyer Brown',
#   'Rascal Flatts',
#   'Montgomery Gentry',
#   'Bryan White',
#   'Chris Young',
#   'Tyler Farr'],
#  'Alan Jackson': ['Tracy Byrd',
#   'Kenny Chesney',
#   'Keith Urban',
#   'Billy Currington',
#   'LeAnn Rimes',
#   'Craig Morgan',
#   'Shania Twain',
#   'Lee Ann Womack',
#   'Mark Chesnutt',
#   'Jason Aldean',
#   'Mark Wills',
#   'Phil Vassar',
#   'The Tractors',
#   'Luke Bryan',
#   'Toby Keith',
#   'Brooks & Dunn',
#   'Tim McGraw',
#   'Brad Paisley',
#   'Jamey Johnson',
#   'Gary Allan',
#   'Wade Bowen',
#   'Carrie Underwood',
#   'Rascal Flatts',
#   'Chris Young',
#   'Logan Mize',
#   'Florida Georgia Line',
#   'Chris Lane'],
#  'Alan Lomax': ['Shirley Collins',
#   'Bob Dylan',
#   'Ewan MacColl',
#   'M. Ward',
#   'Jean Ritchie',
#   'Michael Hurley',
#   'Moby',
#   'Mike Seeger',
#   'Dave Van Ronk',
#   'The Fugs'],
#  'Alan Parsons': ['Starcastle',
#   'Trans-Siberian Orchestra',
#   'Christopher Cross',
#   'Phoenix',
#   'A Flock of Seagulls',
#   'Asia'],
#  'Alanis Morissette': ['Kelly Clarkson',
#   'Fefe Dobson',
#   'Elisa',
#   'Chantal Kreviazuk',
#   'Jason Mraz',
#   'Joss Stone',
#   'Natalie Imbruglia',
#   'Meredith Brooks',
#   'Ashlee Simpson',
#   'Mandy Moore',
#   'Avril Lavigne',
#   'Evanescence',
#   'Shakira',
#   'Vanessa Carlton',
#   'Katy Perry',
#   'Nelly Furtado',
#   'Michelle Branch',
#   'Hilary Duff',
#   'The Veronicas',
#   'P!nk',
#   'Christina Perri',
#   'Meg Myers'],
#  'Albert Ayler': ['Television',
#   'The Last Poets',
#   'Joe Lovano',
#   'Laraaji',
#   'The Flying Luttenbachers',
#   'Pharoah Sanders',
#   'Annette Peacock',
#   'Yoko Ono',
#   'The Lounge Lizards',
#   'Jan Garbarek',
#   'Pere Ubu',
#   'Captain Beefheart'],
#  'Albert Collins': ['Tab Benoit',
#   'Son Seals',
#   'Gary Moore',
#   'Chris Duarte',
#   'The Fabulous Thunderbirds',
#   'Eric Clapton',
#   'John Mayall',
#   'Jeff Beck',
#   'Rory Gallagher',
#   'Roy Buchanan',
#   'Jimmie Vaughan',
#   'Jimi Hendrix',
#   'Stevie Ray Vaughan',
#   'Johnny Winter',
#   'Robert Cray'],
#  'Albert King': ['Tab Benoit',
#   'Ten Years After',
#   'Son Seals',
#   'Sonny Landreth',
#   'Gary Moore',
#   'B.B. King',
#   'Jimmy Reed',
#   'Jimmy Page',
#   'Chris Duarte',
#   'Cream',
#   'Colin James',
#   'Joe Bonamassa',
#   'J.J. Cale',
#   'Chris Thomas',
#   'The Fabulous Thunderbirds',
#   'Luther Allison',
#   'Eric Clapton',
#   'Rory Gallagher',
#   'Roy Buchanan',
#   'Jimmie Vaughan',
#   'Mick Taylor',
#   'The Pretty Things',
#   'William Bell',
#   'Albert Collins',
#   'Stevie Ray Vaughan',
#   'George Thorogood',
#   'ZZ Top',
#   'Booker T. Jones',
#   'Joe Walsh',
#   'Kenny Wayne Shepherd',
#   'Derek & the Dominos',
#   'Robert Cray',
#   'Otis Rush',
#   'Buddy Guy',
#   'Canned Heat',
#   'Junior Wells'],
#  'Alec Wilder': ['Lalo Schifrin'],
#  'Alejandra GuzmÃ¡n': ['Camila'],
#  'Alejandro Escovedo': ['Josh Ritter',
#   'Neko Case',
#   'Justin Townes Earle',
#   'Grant Lee Buffalo',
#   'James McMurtry',
#   'Tift Merritt'],
#  'Alejandro FernÃ¡ndez': ['Alicia Villarreal',
#   'Grupo Mojado',
#   'Fifth Harmony',
#   'Camila Cabello'],
#  'Alejandro Sanz': ['Alicia Villarreal'],
#  'Alex Van Halen': ['Travis Barker'],
#  'Alex de Grassi': ['Kaki King'],
#  "Alexander O'Neal": ['Christopher Williams', 'Dave Hollister'],
#  'Alexandre Pires': ['Luis Fonsi'],
#  'Alfred Newman': ['Dick Hyman',
#   'John Williams',
#   'John Barry',
#   'Jerry Goldsmith',
#   'Randy Newman',
#   'Henry Mancini'],
#  'Alfredo Gutierrez': ['Carlos Vives'],
#  'Ali Akbar Khan': ['Collin Walcott', 'Arthur Russell'],
#  'Ali Farka TourÃ©': ['Oumou Sangare',
#   'Tinariwen',
#   'Toumani DiabatÃ©',
#   'Rokia TraorÃ©',
#   'Mali Music'],
#  'Alice Coltrane': ['Four Tet', 'Matthew Halsall', 'Kadhja Bonet'],
#  'Alice Cooper': ['Soundgarden',
#   'Alice in Chains',
#   'Spinal Tap',
#   'Trans-Siberian Orchestra',
#   'Slash',
#   'The Birthday Party',
#   'Steve Vai',
#   'Bon Jovi',
#   'Insane Clown Posse',
#   'Kiss',
#   'Iron Maiden',
#   'Coheed and Cambria',
#   'The Damned',
#   'The Cult',
#   'Dead Boys',
#   'The Darkness',
#   'Eagles of Death Metal',
#   'Twisted Sister',
#   'Joey Ramone',
#   'Wall of Voodoo',
#   'Gene Simmons',
#   'Type O Negative',
#   'David Lee Roth',
#   'Rob Zombie',
#   'Van Halen',
#   'Dio',
#   'Saigon Kick',
#   'Sammy Hagar',
#   'Peter Criss',
#   'Jerry Cantrell',
#   'Meat Loaf',
#   'Ratt',
#   'Mercyful Fate',
#   'Melvins',
#   'Queens of the Stone Age',
#   'Negative Approach',
#   'Megadeth',
#   'Sex Pistols',
#   'The Replacements',
#   'Ramones',
#   'Monster Magnet',
#   'Mindless Self Indulgence',
#   'MÃ¶tley CrÃ¼e',
#   'Mudhoney',
#   "Guns N' Roses",
#   'AC/DC',
#   'Ace Frehley',
#   'GWAR',
#   'Alien Sex Fiend',
#   'Slipknot',
#   'Skinny Puppy',
#   'Paul Stanley',
#   'Sonic Youth',
#   'King Diamond',
#   'Chris Cornell',
#   'Cradle of Filth',
#   'The Dictators',
#   'Coal Chamber',
#   'Turbonegro',
#   'W.A.S.P.',
#   'White Zombie',
#   'Marilyn Manson',
#   'Quiet Riot',
#   'Misfits',
#   'Hanoi Rocks',
#   'Death',
#   'Black Veil Brides',
#   'Andy Black'],
#  'Alice in Chains': ['Taproot',
#   'Shinedown',
#   'Audioslave',
#   'Silverchair',
#   'Chevelle',
#   'Black Label Society',
#   'Cold',
#   'Clutch',
#   'Sponge',
#   'Staind',
#   'Vision of Disorder',
#   'Days of the New',
#   'Saliva',
#   'Puddle of Mudd',
#   '10 Years',
#   'Queens of the Stone Age',
#   'A Perfect Circle',
#   'Thirty Seconds to Mars',
#   'Our Lady Peace',
#   'Three Days Grace',
#   'Monster Magnet',
#   'Buckcherry',
#   'Candlebox',
#   'Saving Abel',
#   'The Used',
#   'Theory of a Deadman',
#   'Stone Sour',
#   'Bush',
#   'Godsmack',
#   'Avenged Sevenfold',
#   'Volbeat',
#   'Tantric',
#   'Smile Empty Soul',
#   'Kyuss',
#   'Creed',
#   'Finger Eleven',
#   'Deftones',
#   'Hoobastank',
#   'Velvet Revolver',
#   'Bullet for My Valentine',
#   'Nickelback',
#   'Otep',
#   '3 Doors Down',
#   'Breaking Benjamin'],
#  'Alicia Keys': ['Stacie Orrico',
#   'Sara Bareilles',
#   'Karina',
#   'Elle Varner',
#   'Fifth Harmony',
#   'Astrid S'],
#  'Alien Sex Fiend': ['Type O Negative',
#   'Depeche Mode',
#   'Rammstein',
#   'Nine Inch Nails',
#   'Mindless Self Indulgence',
#   'GWAR',
#   'Skinny Puppy',
#   'Evanescence',
#   'Marilyn Manson'],
#  'Alison Krauss': ['Nickel Creek',
#   'Rhonda Vincent',
#   'The Infamous Stringdusters',
#   'Chris Thile',
#   'The SteelDrivers'],
#  'Alkaline Trio': ['Senses Fail',
#   'Hawthorne Heights',
#   'Bayside',
#   'Taking Back Sunday',
#   'Fall Out Boy',
#   'Rise Against',
#   'My Chemical Romance',
#   'From Autumn to Ashes'],
#  'All': ['Rancid',
#   'MxPx',
#   'Sum 41',
#   'H2O',
#   'Good Charlotte',
#   'blink-182',
#   'Jimmy Eat World'],
#  'All That Remains': ['Bring Me the Horizon',
#   'As Blood Runs Black',
#   'All Shall Perish'],
#  'All Time Low': ['5 Seconds of Summer', 'With Confidence'],
#  'All-4-One': ['*NSYNC', 'Day26', 'Backstreet Boys', '112'],
#  'Alla Rakha': ['Collin Walcott', 'Zakir Hussain', 'Philip Glass'],
#  'Allan Holdsworth': ['Eddie Van Halen'],
#  'Allan Jones': ['Andy Williams'],
#  'Allan Sherman': ['Loudon Wainwright III', 'Adam Sandler'],
#  'Allen Toussaint': ['Alicia Keys',
#   'Bill Withers',
#   'King Floyd',
#   'Robert Palmer',
#   'Bonnie Raitt',
#   'Boz Scaggs',
#   'The Dirty Dozen Brass Band',
#   'James Booker',
#   'War',
#   'Dr. John',
#   'Amos Lee',
#   'Little Feat',
#   'Sea Level',
#   'The Meters',
#   'Aaron Neville',
#   'The Box Tops',
#   'Buckwheat Zydeco',
#   'Snooks Eaglin',
#   'Irma Thomas',
#   'Huey "Piano" Smith',
#   'Lowell George',
#   'Norah Jones'],
#  'Alpha': ['Phantogram'],
#  'Alpha Blondy': ['Sizzla',
#   'Bounty Killer',
#   'Jah Cure',
#   'Shaggy',
#   'Richie Spice',
#   'Anthony B',
#   'Capleton',
#   "SinÃ©ad O'Connor",
#   'Beenie Man'],
#  'Alphaville': ['Youth Group',
#   'The Dresden Dolls',
#   'Fischerspooner',
#   'Ladytron',
#   'Death Cab for Cutie'],
#  'Alt-J': ['Little May', 'Dua Lipa'],
#  'Altered Images': ['Life Without Buildings'],
#  'Alton Ellis': ['Ken Boothe',
#   'The Heptones',
#   'King Tubby',
#   'Gregory Isaacs',
#   'U-Roy',
#   'Horace Andy',
#   'I-Roy',
#   'Dennis Brown',
#   'Diana King',
#   'Third World',
#   'The Slits',
#   'Sugar Minott',
#   'Burning Spear',
#   'Steel Pulse',
#   'Beres Hammond',
#   'Maxi Priest'],
#  'Alvin & the Chipmunks': ['Crazy Frog', 'Barney', 'The Muppets'],
#  'Alvin Lee': ['Joe Satriani'],
#  'Amel Larrieux': ['Lianne La Havas', 'JhenÃ© Aiko'],
#  'America': ['Pablo Cruise',
#   'Teenage Fanclub',
#   'Kings of Convenience',
#   'Christopher Cross',
#   'Midlake',
#   'Dan Fogelberg',
#   'Firefall',
#   'Little River Band',
#   'Orleans',
#   'Air Supply',
#   'Rogue Wave',
#   'Dan Hill',
#   'Ween',
#   'Band of Horses',
#   'Alabama',
#   'Fleet Foxes'],
#  'Amerie': ['Tinashe'],
#  'Amos Milburn': ['Charles Mingus',
#   'Jimmy Witherspoon',
#   'Fats Domino',
#   'Dr. John',
#   "Screamin' Jay Hawkins",
#   'Jerry Lee Lewis',
#   'Professor Longhair',
#   'Shuggie Otis',
#   'John Lee Hooker',
#   'Little Richard',
#   'Huey "Piano" Smith',
#   'Canned Heat'],
#  'Amy Grant': ['Steven Curtis Chapman',
#   'Avalon',
#   'Kristin Chenoweth',
#   'Crystal Lewis',
#   'BarlowGirl',
#   'Faith Hill',
#   'Wayne Watson',
#   'Jessica Simpson',
#   'Rich Mullins',
#   'Natalie Grant',
#   'Mindy McCready',
#   'Natasha Bedingfield',
#   'Dallas Holm',
#   '4Him',
#   'Jordin Sparks',
#   "Caedmon's Call"],
#  'Amy Winehouse': ['Daya',
#   'Ellie Goulding',
#   'Sam Smith',
#   'Lana Del Rey',
#   'Kat Dahlia',
#   'Troye Sivan',
#   'Izzy Bizu',
#   'Cloves'],
#  'AmÃ¡lia Rodrigues': ['CesÃ¡ria Ã‰vora',
#   'Nana Mouskouri',
#   'Maria BethÃ¢nia',
#   'Nelly Furtado'],
#  'Ana Gabriel': ['Paulina Rubio', 'Chayanne'],
#  'Anastacia': ['Lady Gaga'],
#  'AndraÃ© Crouch': ['Susan Ashton',
#   'BeBe Winans',
#   'Pat Boone',
#   'BeBe & CeCe Winans',
#   'Walter Hawkins',
#   'Petra',
#   'The Rance Allen Group',
#   'The Winans',
#   'The Brooklyn Tabernacle Choir',
#   'Hezekiah Walker',
#   'Donnie McClurkin',
#   'Israel Houghton',
#   'Carman',
#   'Twila Paris',
#   'Whitney Houston',
#   'CeCe Winans'],
#  'Andrea Bocelli': ['Charlotte Church',
#   'Il Divo',
#   'Clay Aiken',
#   'Katharine McPhee',
#   'Michael BublÃ©',
#   'Tyler Farr'],
#  'Andrew Bird': ['Arcade Fire', 'Clap Your Hands Say Yeah', 'Beirut'],
#  'Andrew Hill': ['Bob Moses',
#   'Keith Jarrett',
#   'Woody Shaw',
#   'Robert Glasper Experiment'],
#  'Andrew Lloyd Webber': ['Trans-Siberian Orchestra',
#   '...And You Will Know Us by the Trail of Dead',
#   'Michael Ball',
#   'CÃ©line Dion',
#   'Dennis DeYoung',
#   'Leo Sayer',
#   'Savatage',
#   'Josh Groban',
#   'Sarah Brightman',
#   'Meat Loaf',
#   'Karen Akers',
#   'Air Supply',
#   'Mandy Patinkin',
#   'Michael BublÃ©'],
#  'AndrÃ© Kostelanetz': ['Liberace'],
#  'Andy Black': ['Steve Miller Band'],
#  'Andy Irvine': ['Clannad'],
#  'Andy Kim': ['The Archies'],
#  'Andy MontaÃ±ez': ['RubÃ©n Blades', 'Ricky Martin', 'Daddy Yankee'],
#  'Andy Williams': ['Tony Orlando',
#   'Barry Manilow',
#   'Carpenters',
#   'B.J. Thomas',
#   'Engelbert Humperdinck',
#   'Julio Iglesias',
#   'Clay Aiken',
#   'Frankie Avalon',
#   'Scott Walker',
#   'Glen Campbell',
#   "Daniel O'Donnell",
#   'Neil Diamond',
#   'Michael BublÃ©'],
#  'Angel Witch': ['Slayer', 'Metallica', 'Iced Earth'],
#  'Angela Bofill': ['Lalah Hathaway',
#   'Sade',
#   'Lisa Stansfield',
#   'Anita Baker',
#   'Regina Belle',
#   'Toni Braxton'],
#  'Angela Winbush': ['Lalah Hathaway'],
#  'Angelic Upstarts': ['Flogging Molly',
#   'Rancid',
#   'Operation Ivy',
#   'Cock Sparrer',
#   'Fugazi',
#   'Dropkick Murphys',
#   'The Mighty Mighty Bosstones',
#   'Agnostic Front'],
#  'Angelo Badalamenti': ['Robin Guthrie',
#   'Moby',
#   'Barry Adamson',
#   'SÃ©bastien Tellier',
#   'Goldfrapp'],
#  'Angels & Airwaves': ['Starset'],
#  'Angie Stone': ['Chrisette Michele',
#   'Donell Jones',
#   'Melanie Fiona',
#   'Elle Varner'],
#  'Ani DiFranco': ['Tegan and Sara',
#   'Kimya Dawson',
#   'Fiona Apple',
#   'Dido',
#   'John Mayer',
#   'Lisa Loeb',
#   'Jewel',
#   'Dashboard Confessional',
#   'Bright Eyes',
#   'Missy Higgins',
#   'Xavier Rudd',
#   'Kaki King',
#   'Alanis Morissette',
#   'Dan Bern'],
#  'Animal Collective': ['Yeasayer',
#   'Passion Pit',
#   'El Guincho',
#   'Local Natives',
#   'Niagara',
#   'Car Seat Headrest',
#   'Elohim'],
#  'Anita Baker': ['Amel Larrieux',
#   'Kelis',
#   'Kem',
#   'Keyshia Cole',
#   'En Vogue',
#   'Erykah Badu',
#   'Vivian Green',
#   'Macy Gray',
#   'Deborah Cox',
#   'Mariah Carey',
#   'Sade',
#   'Vanessa Williams',
#   'Mary J. Blige',
#   'Rachelle Ferrell',
#   'Chrisette Michele',
#   'Jill Scott',
#   'Oleta Adams',
#   'Sunshine Anderson',
#   'Toni Braxton',
#   'Heather Headley',
#   'Leona Lewis'],
#  'Anita Bryant': ['Sandi Patty'],
#  "Anita O'Day": ['Shirley Bassey',
#   'Shirley Horn',
#   'Bernadette Peters',
#   'Lambert, Hendricks & Ross',
#   'Eartha Kitt',
#   'Cassandra Wilson',
#   'Diana Krall',
#   'Jeri Southern',
#   'Petula Clark',
#   'Nancy Wilson',
#   'Nina Simone',
#   'Abbey Lincoln',
#   'Helen Merrill',
#   'Blossom Dearie',
#   'Frank Sinatra',
#   'Etta James',
#   'June Christy'],
#  'Ann Peebles': ['Paul Young',
#   'Angie Stone',
#   'Bette Midler',
#   'Robert Palmer',
#   'Cyndi Lauper',
#   'Graham Parker',
#   'Macy Gray',
#   'Joss Stone',
#   'Annie Lennox',
#   'Tina Turner',
#   'Gloria Gaynor',
#   'Beverley Knight',
#   'Freda Payne',
#   'Humble Pie',
#   'Lowell George',
#   'Jill Scott',
#   "N'Dea Davenport"],
#  'Anne Murray': ['Sheena Easton',
#   'Patty Loveless',
#   'Shania Twain',
#   'CÃ©line Dion',
#   'Marie Osmond',
#   'Lorrie Morgan',
#   'Kathy Mattea',
#   'Natalie Merchant',
#   'Mindy McCready',
#   'Trisha Yearwood',
#   'Suzy Bogguss',
#   'Sarah McLachlan'],
#  'Annette Peacock': ['Lydia Lunch', 'BjÃ¶rk', 'Cat Power'],
#  'Annie Lennox': ['Anastacia',
#   'The Corrs',
#   'Imogen Heap',
#   'Fiona Apple',
#   'Dido',
#   'Sarah Brightman',
#   'Lisa Stansfield',
#   'Martha Wainwright',
#   'Natalie Merchant',
#   'Gwen Stefani',
#   'Natasha Bedingfield',
#   "SinÃ©ad O'Connor",
#   'Jennifer Paige',
#   'Rufus Wainwright',
#   'Rachael Yamagata',
#   'Norah Jones',
#   'Jessie Ware',
#   'Jetta'],
#  'Annie Ross': ["Dr. Buzzard's Original Savannah Band",
#   'Diana Krall',
#   'Joni Mitchell',
#   'The Manhattan Transfer'],
#  'Annihilator': ['Pantera',
#   'Children of Bodom',
#   'DragonForce',
#   'Arch Enemy',
#   'Trivium',
#   'Lamb of God',
#   '3 Inches of Blood'],
#  'Another Bad Creation': ['Pretty Ricky'],
#  'Anthony Hamilton': ['Nick Hakim'],
#  'Anthony Newley': ['David Bowie'],
#  'Anthrax': ['Pantera',
#   'Papa Roach',
#   'Sevendust',
#   'Skindred',
#   'The Black Dahlia Murder',
#   'Soulfly',
#   'Bleeding Through',
#   'Body Count',
#   'Insane Clown Posse',
#   'Kid Rock',
#   'Biohazard',
#   'Korn',
#   'Faith No More',
#   'Unearth',
#   'Disturbed',
#   'DragonForce',
#   'Vision of Disorder',
#   'Death Angel',
#   'Limp Bizkit',
#   'Prong',
#   '311',
#   'Suffocation',
#   'As I Lay Dying',
#   'Hellyeah',
#   'Cannibal Corpse',
#   'Testament',
#   'Bloodhound Gang',
#   'The Dillinger Escape Plan',
#   'Grim Reaper',
#   'Rage Against the Machine'],
#  'Anti-Flag': ['Rise Against',
#   'Chiodos',
#   'Against Me!',
#   'Good Charlotte',
#   'Defiance, Ohio'],
#  'Anti-Nowhere League': ['The Libertines',
#   'Rancid',
#   'Metallica',
#   'Chumbawamba',
#   'Manic Street Preachers'],
#  'Antonio Aguilar': ['Juan Gabriel'],
#  'Antonio MachÃ\xadn': ['Beny MorÃ©'],
#  'AntÃ´nio Carlos Jobim': ['Sergio Mendes',
#   'Amon Tobin',
#   'Stereolab',
#   'Susannah McCorkle',
#   'Azymuth',
#   'The Free Design',
#   'Chico Buarque',
#   'Ivan Lins',
#   'Everything But the Girl',
#   'Tamba Trio',
#   'Bebel Gilberto',
#   'Djavan',
#   'Eliane Elias',
#   'Gal Costa',
#   'CesÃ¡ria Ã‰vora',
#   'Nouvelle Vague',
#   'Wayne Shorter',
#   'CÃ©u',
#   'Pink Martini',
#   'Esperanza Spalding',
#   'Os Mutantes',
#   'Milton Nascimento',
#   'Sting',
#   'George Duke',
#   'The Bird and the Bee',
#   'Maria BethÃ¢nia',
#   'Thievery Corporation',
#   'Caetano Veloso',
#   'Herb Alpert',
#   'EdÃº Lobo',
#   'Nelly Furtado',
#   'Astrud Gilberto',
#   'Tom ZÃ©',
#   'Marcos Valle'],
#  'Anvil': ['Pantera',
#   'Spinal Tap',
#   'Slayer',
#   'Megadeth',
#   'Metallica',
#   'Obituary',
#   'Anthrax',
#   'Annihilator'],
#  'Aphex Twin': ['Kruder & Dorfmeister',
#   'Panda Bear',
#   'Squarepusher',
#   'Deerhunter',
#   'Linkin Park',
#   'Radiohead',
#   'Neurosis',
#   'Thom Yorke',
#   'Caribou',
#   'Seefeel',
#   'Broken Social Scene',
#   'YACHT',
#   'Girl Talk',
#   'The Knife',
#   'Four Tet',
#   'Boards of Canada',
#   'MÃºm',
#   'Deadmau5',
#   'Calvin Harris',
#   'DJ Shadow',
#   'Kodomo',
#   'Fever Ray',
#   'Major Lazer',
#   'Skrillex'],
#  'April March': ['The Bird and the Bee'],
#  'Arcade Fire': ['Imagine Dragons'],
#  'Archers of Loaf': ['Cursive',
#   'Saves the Day',
#   'Modest Mouse',
#   'Brand New',
#   'Motion City Soundtrack'],
#  'Archie Bell & the Drells': ['The Gap Band',
#   'Boyz II Men',
#   'KC & the Sunshine Band',
#   'The Go! Team',
#   'Daryl Hall & John Oates',
#   'The Chi-Lites',
#   'Kool & the Gang',
#   'New York Dolls',
#   'Cameo'],
#  'Archie Shepp': ['The Last Poets', 'Fela Kuti', 'Jan Garbarek'],
#  'Arctic Monkeys': ['Cloves'],
#  'Aretha Franklin': ['Alicia Keys',
#   'Sharon Jones & the Dap-Kings',
#   'Patti LaBelle',
#   'Teena Marie',
#   'Shelby Lynne',
#   'Patty Griffin',
#   'Terry Reid',
#   'Angie Stone',
#   'Gladys Knight',
#   'Bette Midler',
#   'Betty Davis',
#   'Betty Wright',
#   'Natalie Cole',
#   'India.Arie',
#   'Kelly Clarkson',
#   'Labelle',
#   'Lalah Hathaway',
#   'Freddie Mercury',
#   'Joan Armatrading',
#   'Laura Nyro',
#   'Fred Hammond',
#   'BeBe & CeCe Winans',
#   'Dusty Springfield',
#   'En Vogue',
#   'Shania Twain',
#   'Faith Hill',
#   'Dionne Warwick',
#   'Erykah Badu',
#   'Rita Marley',
#   'Janis Joplin',
#   'Eileen Farrell',
#   'Donny Hathaway',
#   'CÃ©line Dion',
#   'Cassandra Wilson',
#   'Luther Vandross',
#   'Janet Jackson',
#   'Rita Coolidge',
#   'Dianne Reeves',
#   'Lizz Wright',
#   'Macy Gray',
#   'Dennis Brown',
#   'Juanes',
#   'Mariah Carey',
#   'Jennifer Hudson',
#   'Joss Stone',
#   'Roberta Flack',
#   'Lisa Stansfield',
#   'Vanessa Williams',
#   'Jennifer Holliday',
#   'Mary J. Blige',
#   'Mary Wells',
#   'Rachelle Ferrell',
#   'Michael W. Smith',
#   'Monica',
#   'Oumou Sangare',
#   'Minnie Riperton',
#   'Thelma Houston',
#   'Candi Staton',
#   'Melody Gardot',
#   'Anita Baker',
#   'Marcia Griffiths',
#   'Annie Lennox',
#   'MÃ³nica Naranjo',
#   'Al Green',
#   'Brenda Russell',
#   'Katharine McPhee',
#   'Donna Summer',
#   'Gloria Gaynor',
#   'Dan Penn',
#   'Phoebe Snow',
#   'Donnie McClurkin',
#   'Sister Sledge',
#   'Paul Carrack',
#   'Sia',
#   'Sylvester',
#   'BeyoncÃ©',
#   'Beverley Knight',
#   'Israel Houghton',
#   'Leela James',
#   'Fantasia',
#   'Chaka Khan',
#   'Vonda Shepard',
#   'Deniece Williams',
#   'Whitney Houston',
#   'Percy Sledge',
#   'Vanessa Bell Armstrong',
#   'Jill Scott',
#   'Oleta Adams',
#   'The Pointer Sisters',
#   'Ann Peebles',
#   'Heather Headley',
#   'Mandisa',
#   'CeCe Winans',
#   'Duffy',
#   'Sharon Jones'],
#  'Argent': ['Kiss',
#   'Genesis',
#   'Phil Collins',
#   'Emerson, Lake & Palmer',
#   'Three Dog Night'],
#  'Arif Mardin': ['David Foster'],
#  'Arlo Guthrie': ['Patty Griffin',
#   'Ani DiFranco',
#   'John Gorka',
#   'Dar Williams',
#   'Suzanne Vega',
#   'The Roches',
#   'Mary Chapin Carpenter'],
#  'Armand Van Helden': ['Crookers', 'Zedd'],
#  'Armin van Buuren': ['Basshunter'],
#  'Arrow': ['Shabba Ranks',
#   'Shaggy',
#   'David Johansen',
#   'Rupee',
#   'Baha Men',
#   'Kevin Lyttle'],
#  'Art Blakey': ['Terence Blanchard',
#   'Chuck Mangione',
#   'Branford Marsalis',
#   'Ray Charles',
#   'Keith Jarrett',
#   "The J.B.'s",
#   'Bill Bruford',
#   'Christian McBride',
#   'Elvin Jones',
#   'Frank Butler',
#   'Jon Hendricks',
#   'Lee Morgan',
#   'Wayne Shorter',
#   'Robert Wyatt',
#   'Ray Barretto',
#   'Jimmy Cobb',
#   'Mulgrew Miller',
#   'Brian Blade',
#   'Ginger Baker',
#   'Manu Dibango',
#   'Woody Shaw',
#   'Soft Machine',
#   'Bobby Timmons',
#   'Bobby Watson',
#   'Billy Cobham',
#   'Charlie Watts',
#   'Chico Hamilton',
#   'Tony Williams',
#   'Eddie Gale',
#   'Freddie Hubbard',
#   'Grady Tate',
#   'Norman Connors',
#   'Philly Joe Jones',
#   'Buddy Miles',
#   'DJ Shadow',
#   'Wynton Marsalis'],
#  'Art Farmer': ['Chuck Mangione',
#   'Roy Hargrove',
#   'Don Cherry',
#   'Hugh Masekela'],
#  'Art Garfunkel': ['Kings of Convenience',
#   'Jack Johnson',
#   'John Mayer',
#   'Jens Lekman',
#   'James Blunt',
#   'Sufjan Stevens',
#   'Xavier Rudd',
#   'JosÃ© GonzÃ¡lez'],
#  'Art Pepper': ['Gato Barbieri',
#   'Charlie Haden',
#   'Bud Shank',
#   'Gary Bartz',
#   'Freddie Hubbard'],
#  'Arthur Conley': ['Tyrone Davis'],
#  'Arthur Lyman': ['Stereolab', 'Martin Denny', 'Pink Martini'],
#  'Arthur Russell': ['Chromatics',
#   'The Disco Biscuits',
#   'The Rapture',
#   'Hercules & Love Affair',
#   'LCD Soundsystem',
#   'Underworld',
#   'Mac DeMarco'],
#  'Artie Shaw': ['Zoot Sims',
#   'Vassar Clements',
#   'Les Baxter',
#   'Mel TormÃ©',
#   'Buddy DeFranco',
#   'Stan Kenton'],
#  'Arvo PÃ¤rt': ['Max Richter',
#   'JÃ³hann JÃ³hannsson',
#   'A Winged Victory for the Sullen'],
#  'Ash': ['The Subways', 'The Cribs'],
#  'Asha Bhosle': ['Cornershop',
#   'Lucky Ali',
#   'Kavita Krishnamurthy',
#   'Jagjit Singh'],
#  'Ashanti': ['JoJo', 'Kristinia DeBarge', 'Tinashe'],
#  'Ashford & Simpson': ['Angie Stone',
#   'Erykah Badu',
#   'The Salsoul Orchestra',
#   'Jill Scott'],
#  'Ashlee Simpson': ['Miley Cyrus',
#   'Hilary Duff',
#   'Vanessa Hudgens',
#   'Demi Lovato'],
#  'Ashley Tisdale': ['Ariana Grande'],
#  'Asia': ['Bon Jovi', 'Europe', 'Mr. Mister', 'Dream Theater', 'Giuffria'],
#  'Asleep at the Wheel': ['Squirrel Nut Zippers',
#   'Lyle Lovett',
#   'Riders in the Sky',
#   'Brad Paisley',
#   'George Strait'],
#  'Astor Piazzolla': ['Julio Iglesias',
#   'Gary Burton',
#   'Kronos Quartet',
#   'Lalo Schifrin'],
#  'Astrud Gilberto': ['Chico Buarque',
#   'Ivy',
#   'Basia',
#   'Everything But the Girl',
#   'Bebel Gilberto',
#   'Feist',
#   'Djavan',
#   'Eliane Elias',
#   'CesÃ¡ria Ã‰vora',
#   'Diana Krall',
#   'Sade',
#   'CÃ©u',
#   'Michael Franks',
#   'Maria BethÃ¢nia',
#   'Thievery Corporation',
#   'Caetano Veloso',
#   'Gilberto Gil',
#   'Keren Ann',
#   'Marisa Monte',
#   'Norah Jones',
#   'Kadhja Bonet'],
#  'Aswad': ['Pato Banton',
#   'Sizzla',
#   'Super Cat',
#   'Big Mountain',
#   'Bad Manners',
#   'Barrington Levy',
#   'UB40',
#   'The English Beat',
#   'Lucky Dube',
#   'The Specials',
#   'The Selecter',
#   'Capleton',
#   'Steel Pulse',
#   'Beres Hammond',
#   'Beenie Man'],
#  'At the Gates': ['All That Remains',
#   'Soilwork',
#   'The Black Dahlia Murder',
#   'Atreyu',
#   'Bleeding Through',
#   'Children of Bodom',
#   'In Flames',
#   'Unearth',
#   'As I Lay Dying',
#   'My Chemical Romance',
#   'Hatebreed',
#   'Killswitch Engage'],
#  'Aterciopelados': ['Bebel Gilberto',
#   'Belanova',
#   'Julieta Venegas',
#   'Natalia Lafourcade'],
#  'Atlanta Rhythm Section': ['Sea Level'],
#  'Atlantic Starr': ['TLC',
#   'All-4-One',
#   'Bobby Brown',
#   'Babyface',
#   'Bell Biv DeVoe',
#   'Johnny Gill'],
#  'Atomic Kitten': ['Aly & AJ',
#   'Ashley Tisdale',
#   'Miley Cyrus',
#   'Danity Kane',
#   'The Cheetah Girls',
#   'Vanessa Hudgens',
#   'The Veronicas',
#   'Little Mix'],
#  'Atomic Rooster': ['Iron Maiden',
#   'Genesis',
#   'QueensrÃ¿che',
#   'Angel Witch',
#   'Emerson, Lake & Palmer',
#   'Dream Theater',
#   'Captain Beyond'],
#  'Audio Adrenaline': ['TobyMac', 'MercyMe'],
#  'Audioslave': ["Jane's Addiction", 'Red Sun Rising'],
#  'Augustus Pablo': ['Squarepusher',
#   'Eek-A-Mouse',
#   'Hugh Mundell',
#   'Scientist',
#   'Thievery Corporation',
#   'Aswad',
#   'Yami Bolo',
#   'Liquid Liquid'],
#  'Aunt Molly Jackson': ['Hazel Dickens'],
#  'Autechre': ['Radiohead', 'Four Tet', 'Ladytron'],
#  'Avail': ['Alkaline Trio',
#   'Fall Out Boy',
#   'Rise Against',
#   'Hot Water Music',
#   'Dillinger Four',
#   'Against Me!',
#   'The Gaslight Anthem'],
#  'Avenged Sevenfold': ['Asking Alexandria', 'Black Veil Brides', 'Andy Black'],
#  'Avicii': ['Kygo', 'Cheat Codes'],
#  'Avril Lavigne': ['Paramore',
#   'Aly & AJ',
#   'Ashley Tisdale',
#   'Busted',
#   'Jonas Brothers',
#   'Miley Cyrus',
#   'Paris Hilton',
#   'Hilary Duff',
#   'Vanessa Hudgens',
#   'Selena Gomez',
#   'Demi Lovato',
#   'Ariana Grande',
#   'Jessie J',
#   'Meghan Trainor'],
#  'Aztec Camera': ['Texas',
#   'The Lightning Seeds',
#   'Kings of Convenience',
#   'Ivy',
#   'Phoenix',
#   'Josh Rouse',
#   'Jellyfish',
#   'Camera Obscura',
#   'Del Amitri'],
#  'B-Movie': ['She Wants Revenge'],
#  'B.B. King': ['Ten Years After',
#   'Son Seals',
#   'Maria Muldaur',
#   'Susan Tedeschi',
#   'Sonny Landreth',
#   'Gary Moore',
#   'Jimmy Page',
#   'Bonnie Raitt',
#   'Larry Carlton',
#   'Cream',
#   'Colin James',
#   'Joe Bonamassa',
#   'J.J. Cale',
#   'Chris Thomas',
#   'The Fabulous Thunderbirds',
#   'Luther Allison',
#   'Flaco JimÃ©nez',
#   'Fleetwood Mac',
#   'Freddie King',
#   'Eric Clapton',
#   'Free',
#   'Warren Haynes',
#   'Zucchero',
#   'Johnny "Big Moose" Walker',
#   'Jeff Beck',
#   'Diane Schuur',
#   'Little Milton',
#   'Rufus Thomas',
#   'Quicksilver Messenger Service',
#   'Roy Buchanan',
#   'Jimmie Vaughan',
#   'Jimi Hendrix',
#   'Koko Taylor',
#   'O.V. Wright',
#   'The Yardbirds',
#   'Albert King',
#   'Stevie Ray Vaughan',
#   'John Scofield',
#   'Z.Z. Hill',
#   'ZZ Top',
#   'Shuggie Otis',
#   'Keith Richards',
#   'Elvin Bishop',
#   'Joe Sample',
#   'Joe Walsh',
#   'Russell Malone',
#   'Delbert McClinton',
#   'Johnny Winter',
#   'Robert Cray',
#   'Savoy Brown',
#   'Peter Green',
#   'Otis Rush',
#   'Buddy Guy',
#   'Canned Heat'],
#  'B.J. Thomas': ['Lee Greenwood', 'Linda Ronstadt'],
#  'B2K': ['Day26', 'Mindless Behavior'],
#  'BBMak': ['Busted'],
#  'Baaba Maal': ['David Byrne',
#   'Afro Celt Sound System',
#   'Peter Gabriel',
#   'Akon'],
#  'Babatunde Olatunji': ['Fela Kuti', 'The Meters', 'Peter Gabriel'],
#  'Babes in Toyland': ['Sleater-Kinney',
#   'The Distillers',
#   'Hole',
#   'Yeah Yeah Yeahs',
#   'The Donnas',
#   'Evanescence',
#   'Veruca Salt'],
#  'Baby Rasta & Gringo': ['Nicky Jam'],
#  'Babyface': ['Tevin Campbell',
#   'Boyz II Men',
#   'Joe',
#   "Colby O'Donis",
#   'Jagged Edge',
#   'Johnny Gill',
#   'Jon B.',
#   'Mario',
#   'Usher',
#   'Rahsaan Patterson',
#   'Ray J',
#   'Monica',
#   'Taio Cruz',
#   'Ginuwine',
#   'Lloyd',
#   'Lyfe Jennings',
#   'Enrique Iglesias',
#   'Jaheim',
#   'Tyrese',
#   'John Legend',
#   'Ne-Yo',
#   'Toni Braxton',
#   'Jeremih',
#   'TGT'],
#  'Bachman-Turner Overdrive': ['Krokus',
#   'Tal Bachman',
#   'Rush',
#   'Van Halen',
#   'Toby Keith',
#   'The Georgia Satellites',
#   'Heart',
#   'Loverboy',
#   'Alabama',
#   'Foreigner'],
#  'Backstreet Boys': ['B*Witched',
#   'Westlife',
#   'S Club 7',
#   'Jennifer Lopez',
#   '*NSYNC',
#   'Jonas Brothers',
#   'Britney Spears',
#   'Enrique Iglesias',
#   'Dream',
#   'Jesse McCartney',
#   'Aaron Carter',
#   'One Direction',
#   'Chris Lane',
#   'Cloves'],
#  'Bad Brains': ['P.O.D.',
#   'Soundgarden',
#   'Sevendust',
#   'Skindred',
#   'Sick of It All',
#   'Biohazard',
#   'Coheed and Cambria',
#   'Corrosion of Conformity',
#   'Faith No More',
#   'Descendents',
#   'Vision of Disorder',
#   'Jeff Buckley',
#   'Poison the Well',
#   'Rancid',
#   'Negative Approach',
#   'Minor Threat',
#   'Ozomatli',
#   'The Suicide Machines',
#   '311',
#   'Sublime',
#   'Anthrax',
#   '7 Seconds',
#   'Thursday',
#   'Glassjaw',
#   'Manu Chao',
#   'Cro-Mags',
#   'Fishbone',
#   'Fugazi',
#   'Government Issue',
#   "Jane's Addiction",
#   'Deftones',
#   'Living Colour',
#   'Rage Against the Machine',
#   'Red Hot Chili Peppers',
#   'Agnostic Front',
#   'Parkway Drive'],
#  'Bad Company': ['Pearl Jam',
#   'Survivor',
#   'The Black Crowes',
#   'Blind Melon',
#   'Bon Jovi',
#   'Billy Squier',
#   'Collective Soul',
#   'The Cult',
#   'Dokken',
#   'Sponge',
#   'Lynyrd Skynyrd',
#   'Europe',
#   'John Parr',
#   'David Lee Roth',
#   'Whitesnake',
#   'White Lion',
#   'Van Halen',
#   'Journey',
#   'Sammy Hagar',
#   'Meat Loaf',
#   'The Raconteurs',
#   'Asia',
#   'Heart',
#   'Seven Mary Three',
#   'Blues Traveler',
#   'The Firm',
#   'John Waite',
#   'Loverboy',
#   'Styx',
#   'Molly Hatchet',
#   'Foreigner'],
#  'Bad Manners': ['Rancid',
#   'No Doubt',
#   'The Suicide Machines',
#   'The Toasters',
#   'The Pietasters',
#   'The Mighty Mighty Bosstones',
#   'Dance Hall Crashers'],
#  'Bad Religion': ['All',
#   'Ten Foot Pole',
#   'Alkaline Trio',
#   'L7',
#   'Kreator',
#   'Green Day',
#   'Rise Against',
#   'Pennywise',
#   'Dillinger Four',
#   'NOFX',
#   'Matchbook Romance',
#   'Rancid',
#   'No Use for a Name',
#   "Plain White T's",
#   'Me First and the Gimme Gimmes',
#   'The Offspring',
#   'The Matches',
#   'Thrice',
#   '7 Seconds',
#   'Sum 41',
#   'AFI',
#   'The Bouncing Souls',
#   'Strung Out',
#   'Yellowcard',
#   'Avenged Sevenfold',
#   'blink-182',
#   'Lagwagon',
#   'Down by Law',
#   'Jawbreaker',
#   'Jimmy Eat World',
#   'Propagandhi',
#   'Anti-Flag',
#   'A Day to Remember',
#   'Zack de la Rocha',
#   'Neck Deep'],
#  'Baden Powell': ['Sergio Mendes',
#   'Chico Buarque',
#   'Gal Costa',
#   'EdÃº Lobo',
#   'Toninho Horta'],
#  'Badfinger': ['Teenage Fanclub',
#   'The Apples in Stereo',
#   'Sloan',
#   'Big Star',
#   'The Knack',
#   'Book of Love',
#   'Cheap Trick',
#   'Bay City Rollers',
#   'Jellyfish',
#   'Matthew Sweet',
#   'Oasis',
#   'The Shins',
#   'Off Broadway',
#   'Michael Penn',
#   'The Only Ones',
#   'The Plimsouls',
#   "The dB's",
#   'The Posies',
#   'The Records',
#   "'Til Tuesday",
#   'Guided by Voices',
#   'Aimee Mann',
#   'XTC',
#   "Enuff Z'nuff",
#   'Phantom Planet',
#   '20/20',
#   'Gin Blossoms'],
#  'Badly Drawn Boy': ['Youth Group', 'The Weepies', 'Gnarls Barkley'],
#  'Bananarama': ['Natalie Imbruglia',
#   'Ace of Base',
#   'Gwen Stefani',
#   'Atomic Kitten',
#   'Amy Winehouse',
#   'The Cheetah Girls',
#   'Keren Ann',
#   'Sugababes',
#   'That Poppy'],
#  'Band of Horses': ['The Lumineers'],
#  'Bappi Lahiri': ['A.R. Rahman'],
#  'Barbara Lynn': ['Sharon Jones & the Dap-Kings',
#   'Lou Ann Barton',
#   'The Ronettes'],
#  'Barbara Mandrell': ['The Judds',
#   'Chely Wright',
#   'Shania Twain',
#   'Faith Hill',
#   'Janie Fricke',
#   'Deana Carter',
#   'Lorrie Morgan',
#   'Reba McEntire',
#   'Suzy Bogguss'],
#  'Barbra Streisand': ['Bernadette Peters',
#   'Charlotte Church',
#   'Bette Midler',
#   'Kristin Chenoweth',
#   'LeAnn Rimes',
#   'Cilla Black',
#   'CÃ©line Dion',
#   'Josh Groban',
#   'Sarah Brightman',
#   'Judy Collins',
#   'Michael Bolton',
#   'Melissa Manchester',
#   'Michael Crawford',
#   'Donna Summer',
#   'Mandy Patinkin',
#   'Idina Menzel',
#   'Whitney Houston'],
#  'Barclay James Harvest': ['Supertramp',
#   'Rush',
#   'Kansas',
#   'Dream Theater',
#   'Styx'],
#  'Barenaked Ladies': ['The Ataris',
#   'The Dandy Warhols',
#   'Ben Kweller',
#   'Fall Out Boy',
#   'Wheatus',
#   'Jason Mraz',
#   'The New Pornographers',
#   'Motion City Soundtrack',
#   'Train',
#   'Something Corporate',
#   'The All-American Rejects',
#   'Bowling for Soup',
#   'Vertical Horizon',
#   'Death Cab for Cutie',
#   'Harvey Danger'],
#  'Barney Kessel': ['Bola Sete',
#   'Kenny Burrell',
#   'Larry Carlton',
#   'Charlie Barnet',
#   'Charlie Parker',
#   'John Abercrombie',
#   'John McLaughlin',
#   'Wes Montgomery',
#   'Jim Hall',
#   'Glen Campbell',
#   'Grant Green',
#   'Tal Farlow',
#   'Pat Martino',
#   'Pete Townshend'],
#  'Barrett Strong': ['Edwin Starr',
#   'The Sonics',
#   'The Supremes',
#   'The Beatles',
#   'The Kingsmen',
#   'The Undisputed Truth'],
#  'Barrington Levy': ['Alpha Blondy',
#   'Sizzla',
#   'Bounty Killer',
#   'Shabba Ranks',
#   'Shaggy',
#   'Cocoa Tea',
#   'Mad Cobra',
#   'Wayne Smith',
#   'Wayne Wonder',
#   'Sean Paul',
#   'Buju Banton',
#   'Damian Marley'],
#  'Barry Adamson': ['Clint Mansell', 'Portishead', 'Goldfrapp'],
#  'Barry Harris': ['Andrew Hill', 'Pepper Adams', 'Herbie Hancock'],
#  'Barry Manilow': ['Pablo Cruise',
#   'Peabo Bryson',
#   'Christopher Cross',
#   'Jack Wagner',
#   'Clay Aiken',
#   'Jason Donovan',
#   'CÃ©line Dion',
#   'Michael Bolton',
#   'James Blunt',
#   'Randy Waldman',
#   'Air Supply',
#   'Gloria Estefan',
#   'Andrea Bocelli',
#   'Michael BublÃ©'],
#  'Barry White': ['Soul II Soul',
#   'Kenny G',
#   'Boyz II Men',
#   'Joe',
#   "D'Angelo",
#   'James Ingram',
#   'Grace Jones',
#   'Freddie Jackson',
#   'Luther Vandross',
#   'Jamie Foxx',
#   'Salaam Remi',
#   'Howard Hewett',
#   'Sade',
#   'Lisa Stansfield',
#   'R. Kelly',
#   'Rick James',
#   'Nate Dogg',
#   'Next',
#   'Nile Rodgers',
#   'ABC',
#   'Al B. Sure!',
#   "Alexander O'Neal",
#   'Gerald Levert',
#   'Dave Hollister',
#   'Simply Red',
#   'Keith Sweat',
#   'Faithless',
#   "Fun Lovin' Criminals",
#   'Maxwell',
#   'Regina Belle'],
#  'Basement Jaxx': ['M.I.A.',
#   'The Go! Team',
#   'Justice',
#   'TÃ©lÃ©popmusik',
#   'Death in Vegas',
#   'The Streets',
#   'Calvin Harris',
#   'Santigold',
#   'The Bloody Beetroots'],
#  'Basia': ['Madeleine Peyroux',
#   "Des'ree",
#   'Diana Krall',
#   'Vonda Shepard',
#   'Jill Scott'],
#  'Bastille': ['Echo & the Bunnymen'],
#  'Bathory': ['Amon Amarth',
#   'Soilwork',
#   'Kreator',
#   'Emperor',
#   'Deicide',
#   'Dimmu Borgir',
#   'Mayhem',
#   'Opeth',
#   'Cannibal Corpse',
#   'Entombed',
#   'Cradle of Filth',
#   'Marilyn Manson',
#   'The Sword',
#   'Morbid Angel'],
#  'Bauhaus': ['Tears for Fears',
#   'Shriekback',
#   'Ikon',
#   'Interpol',
#   'Christian Death',
#   'The Cult',
#   'Gene Loves Jezebel',
#   'Type O Negative',
#   'Dead Can Dance',
#   'She Wants Revenge',
#   'Placebo',
#   'Nitzer Ebb',
#   'Dalis Car',
#   'The Knife',
#   'Alien Sex Fiend',
#   'Skinny Puppy',
#   'The Horrors',
#   'Clan of Xymox',
#   'Flesh for Lulu',
#   "Jane's Addiction"],
#  'Bay City Rollers': ['The Knack',
#   'Take That',
#   'Plastic Bertrand',
#   'New Kids on the Block',
#   'Ramones',
#   'George Michael',
#   'Ashlee Simpson',
#   'Backstreet Boys',
#   'The Donnas',
#   'Aaron Carter',
#   'Hanson'],
#  'Be Bop Deluxe': ['Spandau Ballet',
#   'Television',
#   'Tears for Fears',
#   'The Fixx',
#   'The Cars',
#   'Duran Duran',
#   'Gary Numan',
#   'Japan',
#   'Julian Cope',
#   'Randy Rhoads',
#   'A Flock of Seagulls',
#   'The Teardrop Explodes',
#   'XTC',
#   'Split Enz',
#   'Ultravox',
#   'Peter Gabriel',
#   'Thomas Dolby'],
#  'BeBe & CeCe Winans': ['Smokie Norful',
#   'Kirk Franklin',
#   'TonÃ©x',
#   'Yolanda Adams',
#   'Mary Mary',
#   'Mickey Guyton'],
#  'BeBe Winans': ['Israel Houghton', 'Mandisa'],
#  'Beat Happening': ['Teenage Fanclub',
#   '...And You Will Know Us by the Trail of Dead',
#   'Shonen Knife',
#   'Beulah',
#   'Kimya Dawson',
#   'Beck',
#   'Tullycraft',
#   'Weezer',
#   'Nirvana',
#   'The Moldy Peaches',
#   'Sufjan Stevens',
#   'Bright Eyes',
#   'Hole',
#   'Joanna Newsom',
#   'Fugazi',
#   'Sebadoh',
#   'The Thermals'],
#  'Bebe Neuwirth': ['Kristin Chenoweth'],
#  'Bebo Norman': ['Passion', 'Dave Barnes'],
#  'Bebo ValdÃ©s': ["Paquito D'Rivera"],
#  'Beck': ['The Beta Band',
#   'Kesha',
#   'Cornelius',
#   'Panda Bear',
#   'Cibo Matto',
#   'Ben Kweller',
#   'Blitzen Trapper',
#   'Mason Jennings',
#   'CSS',
#   'Of Montreal',
#   'Mika',
#   'Hot Chip',
#   'Air',
#   'Aimee Mann',
#   'Grandaddy',
#   'Bon Iver',
#   'Gorillaz',
#   'Donavon Frankenreiter',
#   'Beth Orton',
#   'Badly Drawn Boy',
#   'LCD Soundsystem',
#   "Fun Lovin' Criminals",
#   'Nelly Furtado',
#   'Cake',
#   'Gomez',
#   'The Ting Tings',
#   'The Lonely Island'],
#  'Bee Gees': ['Toto',
#   'Tavares',
#   'The 5th Dimension',
#   'Sloan',
#   'Alan Parsons',
#   'Andy Gibb',
#   'Supertramp',
#   'The Lightning Seeds',
#   'Crash Test Dummies',
#   'Chicago',
#   'Crowded House',
#   'Take That',
#   'Electric Light Orchestra',
#   'Fleetwood Mac',
#   'CÃ©line Dion',
#   'Wham!',
#   'Leo Sayer',
#   'Jon B.',
#   'Hot Chocolate',
#   'Maroon 5',
#   'Prefab Sprout',
#   'Lulu',
#   'Marmalade',
#   'Rick Springfield',
#   'New Kids on the Block',
#   'Michael Jackson',
#   'Of Montreal',
#   'Olivia Newton-John',
#   'The New Pornographers',
#   'a-ha',
#   'The Partridge Family',
#   '10cc',
#   'Air Supply',
#   'The Bird and the Bee',
#   'ABC',
#   'Eros Ramazzotti',
#   'Bread',
#   'Split Enz',
#   'Chris de Burgh',
#   'Kylie Minogue',
#   'Scissor Sisters',
#   'Los del Rio',
#   'The Olivia Tremor Control',
#   'ABBA',
#   'Captain & Tennille',
#   'Cake',
#   'Broken Bells',
#   'Nick Jonas',
#   'BÃ˜RNS'],
#  'Beenie Man': ['Sizzla',
#   'Lady Saw',
#   'Shaggy',
#   'Sean Paul',
#   'Red Rat',
#   'Collie Buddz',
#   'Mr. Vegas'],
#  'Belinda Carlisle': ['Natalie Imbruglia'],
#  'Bell Biv DeVoe': ['All-4-One',
#   'SisqÃ³',
#   'Silk',
#   'Blackstreet',
#   'Boyz II Men',
#   'Jagged Edge',
#   'Dru Hill',
#   'Usher',
#   'Ryan Leslie',
#   'Another Bad Creation',
#   'Pretty Ricky',
#   'H-Town',
#   'Ginuwine',
#   '112'],
#  'Belly': ['Stars', 'Feist'],
#  'Ben E. King': ['Teddy Pendergrass',
#   'Bill Withers',
#   "D'Angelo",
#   'Laura Nyro',
#   'Dobie Gray',
#   'Curtis Mayfield',
#   'Barry White',
#   'Joe Tex',
#   'Lionel Richie',
#   'Leon Ware',
#   'Van Morrison',
#   'Marvin Gaye',
#   'Otis Redding',
#   'The Temptations',
#   'Paolo Nutini',
#   'The Spinners',
#   'Al Green',
#   'Harold Melvin & the Blue Notes',
#   'John Legend',
#   "The O'Jays"],
#  'Ben Folds': ['Tegan and Sara',
#   'Ben Kweller',
#   'Jamie Cullum',
#   'Jason Mraz',
#   'Joseph Arthur',
#   'Jonathan Coulton',
#   'Sara Bareilles',
#   'The New Pornographers',
#   'Daniel Powter',
#   "Jack's Mannequin",
#   'Yael NaÃ¯m',
#   'The Decemberists',
#   'Death Cab for Cutie',
#   'The Fray',
#   'Rachael Yamagata',
#   'Relient K',
#   'Never Shout Never',
#   'Jamie Lawson',
#   'A Great Big World'],
#  'Ben Folds Five': ["Jack's Mannequin",
#   'Something Corporate',
#   'Five for Fighting',
#   'The Cab'],
#  'Ben Harper': ['Citizen Cope',
#   'Ray LaMontagne',
#   'M. Ward',
#   'Howie Day',
#   'John Mayer',
#   'Matt Nathanson',
#   'O.A.R.',
#   'Ed Sheeran',
#   'John Newman'],
#  'Ben Lee': ['Ben Kweller',
#   'Dashboard Confessional',
#   'Sufjan Stevens',
#   'Bright Eyes',
# ...
#   'Shaggy',
#   'Don Chezina',
#   'Wayne Smith',
#   'Sean Paul',
#   'Daddy Yankee',
#   'Beenie Man',
#   'Buju Banton',
#   'Damian Marley'],
#  'Eels': ['Andrew Bird',
#   'Snow Patrol',
#   'Elbow',
#   'Midlake',
#   'Ben Kweller',
#   'Pinback',
#   'Richard Hawley',
#   'My Morning Jacket',
#   'The Subways',
#   'The Weakerthans',
#   'Doves',
#   'The Ting Tings'],
#  'Egg': ['The Mars Volta', 'Camel'],
#  'Egg Hunt': ['The Promise Ring'],
#  'El DeBarge': ['Ralph Tresvant', 'Lloyd', 'Ne-Yo', 'Slim', 'Jeremih'],
#  'El General': ['Luny Tunes',
#   'Don Omar',
#   'Calle 13',
#   'Daddy Yankee',
#   'Wisin & Yandel'],
#  'El Gran Combo de Puerto Rico': ['Gilberto Santa Rosa',
#   'Daddy Yankee',
#   'Tony Vega'],
#  'El Tri': ['Molotov'],
#  'Elastica': ['Sleater-Kinney',
#   'Le Tigre',
#   'Bloc Party',
#   'Arctic Monkeys',
#   'Matt and Kim',
#   'Lily Allen',
#   'The Strokes',
#   'Yeah Yeah Yeahs',
#   'Peaches',
#   'The Futureheads',
#   'Kaiser Chiefs'],
#  'Elbow': ['Hot Chelle Rae'],
#  'Electric Light Orchestra': ['The Beautiful South',
#   'Boston',
#   'The Dandy Warhols',
#   'Cut Copy',
#   'Def Leppard',
#   'Phoenix',
#   'Rooney',
#   'Jellyfish',
#   'No Doubt',
#   "The dB's",
#   'Muse',
#   'The Raconteurs',
#   'Rogue Wave',
#   'Air',
#   'Asia',
#   'Grandaddy',
#   'XTC',
#   'Crystal Castles',
#   'Fountains of Wayne',
#   'Stereophonics',
#   'Kylie Minogue',
#   'Scissor Sisters',
#   'World Party',
#   'STRFKR',
#   'Fun.',
#   'Kishi Bashi',
#   'WZRD'],
#  'Electronic': ['Republica'],
#  'Elf': ['Dio', 'Rainbow', 'Black Sabbath'],
#  'Elis Regina': ['Susannah McCorkle',
#   'Carpenters',
#   'Chico Buarque',
#   'Basia',
#   'Bebel Gilberto',
#   'Eliane Elias',
#   'Gal Costa',
#   'Maria Rita',
#   'CÃ©u',
#   'Adriana Calcanhotto',
#   'Maria BethÃ¢nia',
#   'Caetano Veloso',
#   'Keren Ann',
#   'Marisa Monte'],
#  'Elisa': ['BjÃ¶rk'],
#  'Elizabeth Cotten': ['Bob Dylan',
#   'fIREHOSE',
#   'Fred Neil',
#   'Ry Cooder',
#   'M. Ward',
#   'John Fahey',
#   'Pete Seeger',
#   'Hot Tuna',
#   'Peter, Paul and Mary',
#   'Karen Dalton',
#   'Jerry Garcia',
#   'Mike Seeger',
#   'Tim Hardin',
#   'Dave Van Ronk',
#   'Taj Mahal',
#   'Grateful Dead'],
#  'Elizeth Cardoso': ['Beth Carvalho',
#   'Gal Costa',
#   'Sylvia Telles',
#   'Maria BethÃ¢nia',
#   'Elis Regina'],
#  'Ella Fitzgerald': ['Tony Bennett',
#   'Shelby Lynne',
#   'Shirley Horn',
#   'Maria Muldaur',
#   'Smoking Popes',
#   'Gladys Knight',
#   'Susannah McCorkle',
#   'Betty Carter',
#   'Bilal',
#   'Cyndi Lauper',
#   'Everything But the Girl',
#   'Jackie Paris',
#   'Stacey Kent',
#   'Eartha Kitt',
#   'Ben E. King',
#   'Dionne Warwick',
#   'Stacie Orrico',
#   'John Coltrane',
#   'Eileen Farrell',
#   'Flora Purim',
#   'Carmen McRae',
#   'Madeleine Peyroux',
#   'Cassandra Wilson',
#   'Tuck & Patti',
#   'Sarah Vaughan',
#   'Dianne Reeves',
#   'Jamie Cullum',
#   'Janis Ian',
#   'Lizz Wright',
#   'Julie London',
#   'Diana Krall',
#   'Peggy Lee',
#   'Diane Schuur',
#   'Dinah Washington',
#   'Esther Phillips',
#   'Vanessa Williams',
#   'CÃ©u',
#   'Rosemary Clooney',
#   'Rickie Lee Jones',
#   'Nana Mouskouri',
#   'Mary Wells',
#   'Esperanza Spalding',
#   'Maxine Sullivan',
#   'Nina Simone',
#   'Abbey Lincoln',
#   'Keely Smith',
#   'Miriam Makeba',
#   'Adele',
#   'Joan Osborne',
#   'Helen Merrill',
#   'Margaret Whiting',
#   'St. Vincent',
#   'Monica Zetterlund',
#   'Diana Ross',
#   'Al Jarreau',
#   'Gloria Lynne',
#   'Helen Forrest',
#   'Sylvester',
#   'Idina Menzel',
#   'Little Jimmy Scott',
#   'Kurt Elling',
#   'Doris Troy',
#   'Etta James',
#   'Ruth Brown',
#   'Jane Monheit',
#   'June Christy',
#   'Jill Scott',
#   'Barbra Streisand',
#   'KT Tunstall',
#   'ReneÃ© Olstead',
#   'Michael BublÃ©',
#   'Aretha Franklin',
#   'Astrud Gilberto',
#   'Brenda Lee',
#   "Helen O'Connell"],
#  'Ella Mae Morse': ['Sister Rosetta Tharpe'],
#  'Elliott Smith': ['Andrew Bird',
#   'Iron and Wine',
#   'Citizen Cope',
#   'Elbow',
#   'Bayside',
#   'Cass McCombs',
#   'Josh Ritter',
#   'Jens Lekman',
#   'James Blunt',
#   'Okkervil River',
#   'The National',
#   'Sun Kil Moon',
#   'Sufjan Stevens',
#   'Bright Eyes',
#   'Joshua Radin',
#   'Bon Iver',
#   "Jack's Mannequin",
#   'Great Lake Swimmers',
#   'Badly Drawn Boy',
#   'Death Cab for Cutie',
#   'Grizzly Bear',
#   'JosÃ© GonzÃ¡lez',
#   'Band of Horses',
#   'James Morrison',
#   'Someone Still Loves You Boris Yeltsin',
#   'Calexico',
#   'Ed Sheeran',
#   'gnash'],
#  'Elmer Bernstein': ['James Horner',
#   'Dick Hyman',
#   'John Williams',
#   'Howard Shore',
#   'John Barry',
#   'Jerry Goldsmith',
#   'Trevor Jones',
#   'Lalo Schifrin',
#   'James Newton Howard',
#   'Alan Silvestri',
#   'Georges Delerue',
#   'Hans Zimmer'],
#  'Elmore James': ['Pat Travers',
#   'Ten Years After',
#   'Slim Harpo',
#   'Susan Tedeschi',
#   'Bo Diddley',
#   'B.B. King',
#   'Bonnie Raitt',
#   'Chris Rea',
#   'Chuck Berry',
#   'The Fabulous Thunderbirds',
#   'Earl Hooker',
#   "Gov't Mule",
#   'Ry Cooder',
#   'Fleetwood Mac',
#   'Eric Clapton',
#   'Eric Johnson',
#   'John Martyn',
#   'Derek Trucks',
#   'George Harrison',
#   'Hound Dog Taylor',
#   'Zucchero',
#   'John Mayall',
#   'Johnny "Guitar" Watson',
#   'Junior Kimbrough',
#   'Little Feat',
#   'Jerry Lee Lewis',
#   'Rory Gallagher',
#   'Roy Buchanan',
#   'Jimi Hendrix',
#   "Keb' Mo'",
#   'Koko Taylor',
#   'R.L. Burnside',
#   'The Yardbirds',
#   'The Pretty Things',
#   'Albert Collins',
#   'Albert King',
#   'Stevie Ray Vaughan',
#   'George Thorogood',
#   'ZZ Top',
#   'The Allman Brothers Band',
#   'The Animals',
#   'Keith Richards',
#   'Taj Mahal',
#   'Elvin Bishop',
#   'Duane Allman',
#   'Derek & the Dominos',
#   'Johnny Winter',
#   'The Rolling Stones',
#   'Buddy Guy',
#   'Canned Heat',
#   'Grateful Dead'],
#  'Elton John': ['Toto',
#   'Barry Manilow',
#   'Patty Smyth',
#   'Paula Cole',
#   'Beth Nielsen Chapman',
#   'Keith Green',
#   'Boston',
#   'Sheryl Crow',
#   'Keith Urban',
#   'Billy Joel',
#   'Bonnie Tyler',
#   'Christopher Cross',
#   'Christina Milian',
#   'Crowded House',
#   'Gavin DeGraw',
#   'Take That',
#   'Shania Twain',
#   'Ben Folds',
#   'Faith Hill',
#   'Ben Folds Five',
#   'Fiona Apple',
#   'Eels',
#   'Don Henley',
#   'CÃ©line Dion',
#   'Def Leppard',
#   'Westlife',
#   'Jamie Cullum',
#   'Robbie Williams',
#   'Howard Jones',
#   'Rob Zombie',
#   'Wham!',
#   'Leo Sayer',
#   'Hootie & the Blowfish',
#   'Ronan Keating',
#   'Richard Ashcroft',
#   'Pulp',
#   'Luis Fonsi',
#   'Justin Timberlake',
#   'REO Speedwagon',
#   'Phil Collins',
#   'Meat Loaf',
#   'Richard Marx',
#   'Rick Springfield',
#   'Brandi Carlile',
#   'Matthew Sweet',
#   'Michael Bolton',
#   'James Blunt',
#   'Michael W. Smith',
#   'Michael Jackson',
#   'Michel Berger',
#   'Mika',
#   'Air Supply',
#   'Brian McKnight',
#   'Sting',
#   "Guns N' Roses",
#   'Daniel Powter',
#   'George Michael',
#   'Eros Ramazzotti',
#   'Aimee Mann',
#   'Bruce Hornsby',
#   'Gloria Estefan',
#   "Jack's Mannequin",
#   'Marc Cohn',
#   'Train',
#   'Something Corporate',
#   'Tori Amos',
#   'Five for Fighting',
#   'Debbie Gibson',
#   'Scissor Sisters',
#   'Roxy Music',
#   'Rufus Wainwright',
#   'Kate Bush',
#   'Queen',
#   'Norah Jones',
#   'James Morrison',
#   'A Great Big World'],
#  'Elvin Bishop': ['Derek Trucks',
#   'Jimmie Vaughan',
#   'George Thorogood',
#   'Robert Cray'],
#  'Elvin Jones': ['Shelly Manne',
#   'Bill Bruford',
#   'Collin Walcott',
#   'Jack DeJohnette',
#   'Cream',
#   'Lenny White',
#   'Robert Wyatt',
#   'Ginger Baker',
#   'Charlie Watts',
#   'Tony Williams',
#   'Grady Tate',
#   'Jan Hammer',
#   'Peter Erskine',
#   'Norman Connors',
#   'Buddy Miles'],
#  'Elvis Costello': ['Tasmin Archer',
#   'Smash Mouth',
#   'Sloan',
#   'The Beautiful South',
#   'Smoking Popes',
#   'Paul Westerberg',
#   'Angela McCluskey',
#   'Simple Plan',
#   'Billy Bragg',
#   'James',
#   'Crowded House',
#   'Spoon',
#   'Fastball',
#   'Ben Folds',
#   'Ben Kweller',
#   'Elliott Smith',
#   'Eels',
#   'Foo Fighters',
#   'Lenny Kravitz',
#   'David Gray',
#   'Joseph Arthur',
#   'Josh Ritter',
#   'Razorlight',
#   'Weezer',
#   'Dexys Midnight Runners',
#   'Jon Brion',
#   'Pulp',
#   'Radiohead',
#   'Prince',
#   'Matthew Sweet',
#   'OK Go',
#   'Michael Penn',
#   'The Matches',
#   'The National',
#   'The New Pornographers',
#   'The Pogues',
#   'They Might Be Giants',
#   '10,000 Maniacs',
#   'Dashboard Confessional',
#   'The Wallflowers',
#   'The Weakerthans',
#   'Damien Rice',
#   'Daniel Johnston',
#   'Paul Kelly',
#   'Suzanne Vega',
#   'Aztec Camera',
#   'The Go-Betweens',
#   'INXS',
#   'Chris Cornell',
#   'The Futureheads',
#   'Fishbone',
#   'Freedy Johnston',
#   'John Hiatt',
#   'Jenny Lewis',
#   'Phantom Planet',
#   'Men at Work',
#   'The Smithereens',
#   'Girls',
#   'Matthew Koma'],
#  'Elvis Costello & the Attractions': ['French Kicks',
#   'Hot Hot Heat',
#   'Huey Lewis & the News'],
#  'Elvis Presley': ['T. Rex',
#   'Tanya Tucker',
#   'Shelby Lynne',
#   'Terry Stafford',
#   'Paul McCartney',
#   'Solomon Burke',
#   'Paul Simon',
#   'Steve Harley',
#   'Social Distortion',
#   'Simon & Garfunkel',
#   'Bee Gees',
#   'The Everly Brothers',
#   'B.J. Thomas',
#   'Elvis Costello',
#   'The Bobby Fuller Four',
#   'Bobby Bare',
#   'Bob Dylan',
#   'Billy Idol',
#   'Bob Seger',
#   'The Clash',
#   'Billy Fury',
#   'Billy Joe Royal',
#   'The Judds',
#   'The Knack',
#   'Ian Hunter',
#   'Chico Buarque',
#   'Engelbert Humperdinck',
#   'Connie Smith',
#   'Julio Iglesias',
#   'Cher',
#   'Hank Williams, Jr.',
#   'Jacques Dutronc',
#   'Jackie DeShannon',
#   'Freddie Mercury',
#   'Jackson C. Frank',
#   'Creedence Clearwater Revival',
#   'Larry Norman',
#   'The Beau Brummels',
#   'The Cramps',
#   'Led Zeppelin',
#   'Eddy Raven',
#   'Joe Ely',
#   'Cliff Richard',
#   'Pat Benatar',
#   'Frankie Avalon',
#   'Joe Strummer',
#   'Carole King',
#   'Ry Cooder',
#   'Fleetwood Mac',
#   'Fine Young Cannibals',
#   'Gary Stewart',
#   'Mac Davis',
#   'Freddy Fender',
#   'Del Shannon',
#   'Don Williams',
#   'Doug Sahm',
#   'Waylon Jennings',
#   'Gene Pitney',
#   'Gene Simmons',
#   'Johnny Rivers',
#   'Dr. Feelgood',
#   'Ricky Van Shelton',
#   'George Harrison',
#   'Ringo Starr',
#   'John Fogerty',
#   'Jeff Lynne',
#   'John Lennon',
#   'Lou Reed',
#   'Lee Hazlewood',
#   'Sandi Patty',
#   'Johnny Kidd & the Pirates',
#   'Jon Lucien',
#   'Johnny Hallyday',
#   'JosÃ© Feliciano',
#   'Ritchie Valens',
#   'Ronan Keating',
#   'Robert Gordon',
#   'Sam the Sham & the Pharaohs',
#   'Roger Daltrey',
#   'Luis Miguel',
#   'Neil Sedaka',
#   'Ronnie Hawkins',
#   'Phil Ochs',
#   'Ronnie Milsap',
#   'Rory Gallagher',
#   'Richard Hawley',
#   'NRBQ',
#   'Neil Young',
#   'Nick Cave',
#   'The Mavericks',
#   'Merle Haggard',
#   'The Righteous Brothers',
#   'Mick Ronson',
#   'Stray Cats',
#   'The Move',
#   'Suicide',
#   'Annette Peacock',
#   'Anne Murray',
#   'The Shadows',
#   'Mink DeVille',
#   'Brian Hyland',
#   'Brian Setzer',
#   'Bruce Springsteen',
#   'Buddy Holly',
#   'Gerry & the Pacemakers',
#   'George Michael',
#   'Harry Nilsson',
#   'The Modern Lovers',
#   "Herman's Hermits",
#   'Dave Edmunds',
#   'Tom Jones',
#   'Tommy Sands',
#   'Brian Wilson',
#   'David Allan Coe',
#   'Jason Derulo',
#   'Glenn Frey',
#   'Glen Campbell',
#   'Malcolm McLaren',
#   'Dan Penn',
#   'Dave Dee, Dozy, Beaky, Mick & Tich',
#   'Wynonna',
#   'Volbeat',
#   'Townes Van Zandt',
#   'Spiritualized',
#   'Trisha Yearwood',
#   'The Animals',
#   'The Beatles',
#   'The Blasters',
#   'The Fugs',
#   'Bob Luman',
#   'The Collins Kids',
#   'Bobby Vinton',
#   'Keith Richards',
#   'The Kingsmen',
#   'Chris Isaak',
#   'Conway Twitty',
#   'Dead Kennedys',
#   'Dwight Yoakam',
#   'Eddie Rabbitt',
#   'Elton John',
#   'Gene Vincent',
#   'Charlie Daniels',
#   'Wanda Jackson',
#   'Levon Helm',
#   'Robert Plant',
#   'Jim Ford',
#   'Roy Orbison',
#   'Roxy Music',
#   'Marshall Crenshaw',
#   'Queen',
#   'Neil Diamond',
#   'New York Dolls',
#   'Nick Lowe',
#   'Misfits',
#   'Mick Jagger',
#   'The Rolling Stones',
#   'The Searchers',
#   'Styx',
#   'Wings',
#   'Danzig',
#   'Gram Parsons',
#   'Bruno Mars',
#   'Ida Maria',
#   'Lana Del Rey',
#   'Harry Styles',
#   'BÃ˜RNS'],
#  'Emerson, Lake & Palmer': ['Starcastle',
#   'Trans-Siberian Orchestra',
#   'Boston',
#   'Europe',
#   'Rush',
#   'U.K.',
#   'Journey',
#   'Kansas',
#   'Opeth',
#   'Return to Forever',
#   'Asia',
#   'Mannheim Steamroller',
#   'Yanni',
#   'Dream Theater',
#   'Marillion',
#   'Styx',
#   'Thomas Dolby'],
#  'EmilÃ\xadana Torrini': ['Lana Del Rey'],
#  'Emitt Rhodes': ['Jellyfish',
#   'Matthew Sweet',
#   "The dB's",
#   'Sufjan Stevens',
#   'The Smithereens',
#   'Mac DeMarco'],
#  'Emmanuel': ['Luis Miguel', 'Menudo'],
#  'Emmure': ['Of Mice & Men'],
#  'Emmylou Harris': ['Travis Tritt',
#   'Patty Loveless',
#   'Patty Griffin',
#   'The Be Good Tanyas',
#   'Texas',
#   'Sheryl Crow',
#   'Keith Whitley',
#   'Iris DeMent',
#   'The Judds',
#   'Cowboy Junkies',
#   'Carlene Carter',
#   'Faith Hill',
#   'Dixie Chicks',
#   'Jane Siberry',
#   'Vince Gill',
#   'Whiskeytown',
#   'Rosanne Cash',
#   'Lorrie Morgan',
#   'Rodney Crowell',
#   'Nanci Griffith',
#   'Kathy Mattea',
#   'Neko Case',
#   'Randy Travis',
#   'Anne Murray',
#   'Miranda Lambert',
#   'Gillian Welch',
#   'The Wreckers',
#   'Dar Williams',
#   'Wynonna',
#   'Alison Krauss',
#   'Trisha Yearwood',
#   'Ryan Adams',
#   'Jenny Lewis',
#   'Lori McKenna',
#   'Lucinda Williams',
#   'Juice Newton',
#   'k.d. lang',
#   'Mary Chapin Carpenter',
#   'Tift Merritt'],
#  'Emperor': ['Bleeding Through', 'Dimmu Borgir', 'Burzum', 'Cradle of Filth'],
#  'En Vogue': ['Total',
#   'Spice Girls',
#   "Destiny's Child",
#   "Lil' Mo",
#   'Lucy Pearl',
#   'Jennifer Lopez',
#   'Michelle Williams',
#   '3LW',
#   'Monica',
#   'Aaliyah',
#   'Brandy',
#   'Mya',
#   'Britney Spears',
#   'Keri Hilson',
#   'BeyoncÃ©',
#   'Cherish',
#   'Dream',
#   'Mary Mary',
#   'Sugababes',
#   'Ashanti',
#   'P!nk',
#   'Little Mix'],
#  'Enchantment': ['Peabo Bryson'],
#  'Engelbert Humperdinck': ['Barry Manilow',
#   'Bette Midler',
#   'Cher',
#   'CÃ©line Dion',
#   'Josh Groban',
#   'Sarah Brightman',
#   'Linda Eder',
#   'Ricky Martin',
#   'Michael Bolton',
#   'Melissa Manchester',
#   'Michael Crawford',
#   'Mandy Patinkin',
#   'Gino Vannelli'],
#  'Enigma': ['Trans-Siberian Orchestra', 'Lemon Jelly', 'Goldfrapp'],
#  'Ennio Morricone': ['Alpha',
#   'Angelo Badalamenti',
#   'Blonde Redhead',
#   'Craig Armstrong',
#   'Blue States',
#   'Labradford',
#   'Carter Burwell',
#   'Tortoise',
#   'Wall of Voodoo',
#   'DeVotchKa',
#   'Zucchero',
#   'Scott Walker',
#   'Portishead',
#   'Massive Attack',
#   'Nick Cave',
#   'The Residents',
#   'Adam Ant',
#   'Mr. Bungle',
#   'Danny Elfman',
#   'Tindersticks',
#   'Giorgio Moroder',
#   'Godspeed You! Black Emperor',
#   'Big Audio Dynamite',
#   'Barry Adamson',
#   'Broadcast',
#   'Calexico',
#   'Goldfrapp',
#   'Dan the Automator',
#   'Hans Zimmer',
#   'Christopher Tin'],
#  'Enrique GuzmÃ¡n': ['Marco Antonio SolÃ\xads'],
#  'Enrique Iglesias': ['Juanes',
#   'Mario',
#   'Camila',
#   'Ryan Cabrera',
#   'ThalÃ\xada',
#   'Nicole Scherzinger'],
#  'Entombed': ['Soilwork',
#   'The Black Dahlia Murder',
#   'Bleeding Through',
#   'In Flames',
#   'Converge',
#   'Mastodon',
#   'Opeth',
#   'Meshuggah',
#   'At the Gates'],
#  'Enya': ['Charlotte Church',
#   'Enigma',
#   'Celtic Woman',
#   'Sarah Brightman',
#   'Jim Brickman',
#   'Loreena McKennitt'],
#  'Erasure': ['Cut Copy',
#   'Felix da Housecat',
#   'Fischerspooner',
#   'Ladytron',
#   'Savage Garden',
#   'Kaskade',
#   'The Postal Service',
#   '808 State',
#   'La Roux'],
#  'Eric BenÃ©t': ['Jaheim', 'Ne-Yo'],
#  'Eric Burdon': ['The Black Crowes',
#   'Ian Hunter',
#   'Graham Parker',
#   'War',
#   'John Mellencamp',
#   'Bruce Springsteen',
#   'Dave Edmunds',
#   'Tom Petty',
#   'The Georgia Satellites',
#   'Ryan Adams',
#   'The White Stripes'],
#  'Eric Carmen': ['Clay Aiken'],
#  'Eric Clapton': ['Pat Travers',
#   'Brian May',
#   'Slash',
#   'Susan Tedeschi',
#   'Sonny Landreth',
#   'Steve Vai',
#   'Gary Moore',
#   'The Jeff Healey Band',
#   'Sheryl Crow',
#   'Keith Urban',
#   'Billy Squier',
#   'Jimmy Page',
#   'Blackfoot',
#   'Chris Rea',
#   'Colin James',
#   'Joe Bonamassa',
#   'Eddie Van Halen',
#   'Dire Straits',
#   'Lynyrd Skynyrd',
#   'Eric Johnson',
#   'Lenny Kravitz',
#   'Derek Trucks',
#   'Van Halen',
#   'Jonny Lang',
#   'Rossington Collins Band',
#   'Peter Frampton',
#   'Jimmie Vaughan',
#   'Rainbow',
#   'Mick Ronson',
#   'Ace Frehley',
#   'Stevie Ray Vaughan',
#   'Bruce Hornsby',
#   'Dave Matthews',
#   'ZZ Top',
#   'Ted Nugent',
#   'Joe Satriani',
#   'Joe Walsh',
#   'Kenny Wayne Shepherd',
#   'Robert Cray',
#   'Mark Knopfler',
#   'Robin Trower',
#   'Ocean Colour Scene',
#   'The Outlaws',
#   'Molly Hatchet',
#   'Tommy Bolin',
#   'Sheppard'],
#  'Eric Dolphy': ['Terence Blanchard',
#   'Bill Frisell',
#   'Frank Zappa',
#   'Donald Harrison',
#   'John Handy',
#   'Wayne Shorter',
#   'Sam Rivers',
#   'Archie Shepp',
#   'Dave Holland',
#   'Woody Shaw',
#   'The Lounge Lizards',
#   'Freddie Hubbard',
#   'Rahsaan Roland Kirk'],
#  ...}

# %%
graph1 = df_inf.groupby('artist_names')['follower_name'].apply(lambda x: x.tolist()).to_dict()

# %%
from queue import Queue
visited = {}
level = {}
parent = {}
traversal_output = []
queue = Queue()

# %%
for node in graph1.keys():
        visited[node] = False
        parent[node] = None
        level[node] = -1

# %%
s = "Eric Dolphy"
visited[s] = True
level[s] = 0
queue.put(s)

# %%
while not queue.empty():
    u = queue.get()
    traversal_output.append(u)
    for v in graph1[u]:
        if not visited[v]:
            visited[v] = True
            parent[v] = u
            level[v] = level[u] + 1
            queue.put(v)
            
print(traversal_output)
print(visited)
print(level)
print(parent)
# Out:
# ['Eric Dolphy']
# {"'Til Tuesday": False, '*NSYNC': False, '10,000 Maniacs': False, '10cc': False, '112': False, '1910 Fruitgum Company': False, '20/20': False, '3 Doors Down': False, '311': False, '4 Non Blondes': False, '54-40': False, '7 Seconds': False, '808 State': False, '999': False, '? & the Mysterians': False, 'A Certain Ratio': False, 'A Flock of Seagulls': False, 'A Guy Called Gerald': False, 'A Perfect Circle': False, 'A*Teens': False, 'A.C. Reed': False, 'A.R. Kane': False, 'ABBA': False, 'ABC': False, 'AC/DC': False, 'AFI': False, 'ATB': False, 'Aaliyah': False, 'Aaron Carter': False, 'Aaron Neville': False, 'Aaron Tippin': False, 'Abbey Lincoln': False, 'Accept': False, 'Ace': False, 'Ace Frehley': False, 'Ace of Base': False, 'Acker Bilk': False, 'Adam Ant': False, 'Adam Sandler': False, 'Adamski': False, 'Adele': False, 'Adina Howard': False, 'Admiral Bailey': False, 'Adolescents': False, 'Adriano Celentano': False, 'Aerosmith': False, 'Agent Orange': False, 'Agnostic Front': False, 'Ahmad Jamal': False, 'Aimee Mann': False, 'Air': False, 'Air Supply': False, 'Akon': False, 'Al B. Sure!': False, 'Al Bowlly': False, 'Al Cohn': False, 'Al Di Meola': False, 'Al Green': False, 'Al Jarreau': False, 'Al Kooper': False, 'Al Martino': False, 'Al Stewart': False, 'Alabama': False, 'Alan Jackson': False, 'Alan Lomax': False, 'Alan Parsons': False, 'Alanis Morissette': False, 'Albert Ayler': False, 'Albert Collins': False, 'Albert King': False, 'Alec Wilder': False, 'Alejandra GuzmÃ¡n': False, 'Alejandro Escovedo': False, 'Alejandro FernÃ¡ndez': False, 'Alejandro Sanz': False, 'Alex Van Halen': False, 'Alex de Grassi': False, "Alexander O'Neal": False, 'Alexandre Pires': False, 'Alfred Newman': False, 'Alfredo Gutierrez': False, 'Ali Akbar Khan': False, 'Ali Farka TourÃ©': False, 'Alice Coltrane': False, 'Alice Cooper': False, 'Alice in Chains': False, 'Alicia Keys': False, 'Alien Sex Fiend': False, 'Alison Krauss': False, 'Alkaline Trio': False, 'All': False, 'All That Remains': False, 'All Time Low': False, 'All-4-One': False, 'Alla Rakha': False, 'Allan Holdsworth': False, 'Allan Jones': False, 'Allan Sherman': False, 'Allen Toussaint': False, 'Alpha': False, 'Alpha Blondy': False, 'Alphaville': False, 'Alt-J': False, 'Altered Images': False, 'Alton Ellis': False, 'Alvin & the Chipmunks': False, 'Alvin Lee': False, 'Amel Larrieux': False, 'America': False, 'Amerie': False, 'Amos Milburn': False, 'Amy Grant': False, 'Amy Winehouse': False, 'AmÃ¡lia Rodrigues': False, 'Ana Gabriel': False, 'Anastacia': False, 'AndraÃ© Crouch': False, 'Andrea Bocelli': False, 'Andrew Bird': False, 'Andrew Hill': False, 'Andrew Lloyd Webber': False, 'AndrÃ© Kostelanetz': False, 'Andy Black': False, 'Andy Irvine': False, 'Andy Kim': False, 'Andy MontaÃ±ez': False, 'Andy Williams': False, 'Angel Witch': False, 'Angela Bofill': False, 'Angela Winbush': False, 'Angelic Upstarts': False, 'Angelo Badalamenti': False, 'Angels & Airwaves': False, 'Angie Stone': False, 'Ani DiFranco': False, 'Animal Collective': False, 'Anita Baker': False, 'Anita Bryant': False, "Anita O'Day": False, 'Ann Peebles': False, 'Anne Murray': False, 'Annette Peacock': False, 'Annie Lennox': False, 'Annie Ross': False, 'Annihilator': False, 'Another Bad Creation': False, 'Anthony Hamilton': False, 'Anthony Newley': False, 'Anthrax': False, 'Anti-Flag': False, 'Anti-Nowhere League': False, 'Antonio Aguilar': False, 'Antonio MachÃ\xadn': False, 'AntÃ´nio Carlos Jobim': False, 'Anvil': False, 'Aphex Twin': False, 'April March': False, 'Arcade Fire': False, 'Archers of Loaf': False, 'Archie Bell & the Drells': False, 'Archie Shepp': False, 'Arctic Monkeys': False, 'Aretha Franklin': False, 'Argent': False, 'Arif Mardin': False, 'Arlo Guthrie': False, 'Armand Van Helden': False, 'Armin van Buuren': False, 'Arrow': False, 'Art Blakey': False, 'Art Farmer': False, 'Art Garfunkel': False, 'Art Pepper': False, 'Arthur Conley': False, 'Arthur Lyman': False, 'Arthur Russell': False, 'Artie Shaw': F ...
# {"'Til Tuesday": -1, '*NSYNC': -1, '10,000 Maniacs': -1, '10cc': -1, '112': -1, '1910 Fruitgum Company': -1, '20/20': -1, '3 Doors Down': -1, '311': -1, '4 Non Blondes': -1, '54-40': -1, '7 Seconds': -1, '808 State': -1, '999': -1, '? & the Mysterians': -1, 'A Certain Ratio': -1, 'A Flock of Seagulls': -1, 'A Guy Called Gerald': -1, 'A Perfect Circle': -1, 'A*Teens': -1, 'A.C. Reed': -1, 'A.R. Kane': -1, 'ABBA': -1, 'ABC': -1, 'AC/DC': -1, 'AFI': -1, 'ATB': -1, 'Aaliyah': -1, 'Aaron Carter': -1, 'Aaron Neville': -1, 'Aaron Tippin': -1, 'Abbey Lincoln': -1, 'Accept': -1, 'Ace': -1, 'Ace Frehley': -1, 'Ace of Base': -1, 'Acker Bilk': -1, 'Adam Ant': -1, 'Adam Sandler': -1, 'Adamski': -1, 'Adele': -1, 'Adina Howard': -1, 'Admiral Bailey': -1, 'Adolescents': -1, 'Adriano Celentano': -1, 'Aerosmith': -1, 'Agent Orange': -1, 'Agnostic Front': -1, 'Ahmad Jamal': -1, 'Aimee Mann': -1, 'Air': -1, 'Air Supply': -1, 'Akon': -1, 'Al B. Sure!': -1, 'Al Bowlly': -1, 'Al Cohn': -1, 'Al Di Meola': -1, 'Al Green': -1, 'Al Jarreau': -1, 'Al Kooper': -1, 'Al Martino': -1, 'Al Stewart': -1, 'Alabama': -1, 'Alan Jackson': -1, 'Alan Lomax': -1, 'Alan Parsons': -1, 'Alanis Morissette': -1, 'Albert Ayler': -1, 'Albert Collins': -1, 'Albert King': -1, 'Alec Wilder': -1, 'Alejandra GuzmÃ¡n': -1, 'Alejandro Escovedo': -1, 'Alejandro FernÃ¡ndez': -1, 'Alejandro Sanz': -1, 'Alex Van Halen': -1, 'Alex de Grassi': -1, "Alexander O'Neal": -1, 'Alexandre Pires': -1, 'Alfred Newman': -1, 'Alfredo Gutierrez': -1, 'Ali Akbar Khan': -1, 'Ali Farka TourÃ©': -1, 'Alice Coltrane': -1, 'Alice Cooper': -1, 'Alice in Chains': -1, 'Alicia Keys': -1, 'Alien Sex Fiend': -1, 'Alison Krauss': -1, 'Alkaline Trio': -1, 'All': -1, 'All That Remains': -1, 'All Time Low': -1, 'All-4-One': -1, 'Alla Rakha': -1, 'Allan Holdsworth': -1, 'Allan Jones': -1, 'Allan Sherman': -1, 'Allen Toussaint': -1, 'Alpha': -1, 'Alpha Blondy': -1, 'Alphaville': -1, 'Alt-J': -1, 'Altered Images': -1, 'Alton Ellis': -1, 'Alvin & the Chipmunks': -1, 'Alvin Lee': -1, 'Amel Larrieux': -1, 'America': -1, 'Amerie': -1, 'Amos Milburn': -1, 'Amy Grant': -1, 'Amy Winehouse': -1, 'AmÃ¡lia Rodrigues': -1, 'Ana Gabriel': -1, 'Anastacia': -1, 'AndraÃ© Crouch': -1, 'Andrea Bocelli': -1, 'Andrew Bird': -1, 'Andrew Hill': -1, 'Andrew Lloyd Webber': -1, 'AndrÃ© Kostelanetz': -1, 'Andy Black': -1, 'Andy Irvine': -1, 'Andy Kim': -1, 'Andy MontaÃ±ez': -1, 'Andy Williams': -1, 'Angel Witch': -1, 'Angela Bofill': -1, 'Angela Winbush': -1, 'Angelic Upstarts': -1, 'Angelo Badalamenti': -1, 'Angels & Airwaves': -1, 'Angie Stone': -1, 'Ani DiFranco': -1, 'Animal Collective': -1, 'Anita Baker': -1, 'Anita Bryant': -1, "Anita O'Day": -1, 'Ann Peebles': -1, 'Anne Murray': -1, 'Annette Peacock': -1, 'Annie Lennox': -1, 'Annie Ross': -1, 'Annihilator': -1, 'Another Bad Creation': -1, 'Anthony Hamilton': -1, 'Anthony Newley': -1, 'Anthrax': -1, 'Anti-Flag': -1, 'Anti-Nowhere League': -1, 'Antonio Aguilar': -1, 'Antonio MachÃ\xadn': -1, 'AntÃ´nio Carlos Jobim': -1, 'Anvil': -1, 'Aphex Twin': -1, 'April March': -1, 'Arcade Fire': -1, 'Archers of Loaf': -1, 'Archie Bell & the Drells': -1, 'Archie Shepp': -1, 'Arctic Monkeys': -1, 'Aretha Franklin': -1, 'Argent': -1, 'Arif Mardin': -1, 'Arlo Guthrie': -1, 'Armand Van Helden': -1, 'Armin van Buuren': -1, 'Arrow': -1, 'Art Blakey': -1, 'Art Farmer': -1, 'Art Garfunkel': -1, 'Art Pepper': -1, 'Arthur Conley': -1, 'Arthur Lyman': -1, 'Arthur Russell': -1, 'Artie Shaw': -1, 'Arvo PÃ¤rt': -1, 'Ash': -1, 'Asha Bhosle': -1, 'Ashanti': -1, 'Ashford & Simpson': -1, 'Ashlee Simpson': -1, 'Ashley Tisdale': -1, 'Asia': -1, 'Asleep at the Wheel': -1, 'Astor Piazzolla': -1, 'Astrud Gilberto': -1, 'Aswad': -1, 'At the Gates': -1, 'Aterciopelados': -1, 'Atlanta Rhythm Section': -1, 'Atlantic Starr': -1, 'Atomic Kitten': -1, 'Atomic Rooster': -1, 'Audio Adrenaline': -1, 'Audioslave': -1, 'Augustus Pablo': -1, 'Aunt Molly Jackson': -1, 'Autechre': -1, 'Avail': -1, 'Avenged Sevenfold': -1, 'Avicii': -1,  ...
# {"'Til Tuesday": None, '*NSYNC': None, '10,000 Maniacs': None, '10cc': None, '112': None, '1910 Fruitgum Company': None, '20/20': None, '3 Doors Down': None, '311': None, '4 Non Blondes': None, '54-40': None, '7 Seconds': None, '808 State': None, '999': None, '? & the Mysterians': None, 'A Certain Ratio': None, 'A Flock of Seagulls': None, 'A Guy Called Gerald': None, 'A Perfect Circle': None, 'A*Teens': None, 'A.C. Reed': None, 'A.R. Kane': None, 'ABBA': None, 'ABC': None, 'AC/DC': None, 'AFI': None, 'ATB': None, 'Aaliyah': None, 'Aaron Carter': None, 'Aaron Neville': None, 'Aaron Tippin': None, 'Abbey Lincoln': None, 'Accept': None, 'Ace': None, 'Ace Frehley': None, 'Ace of Base': None, 'Acker Bilk': None, 'Adam Ant': None, 'Adam Sandler': None, 'Adamski': None, 'Adele': None, 'Adina Howard': None, 'Admiral Bailey': None, 'Adolescents': None, 'Adriano Celentano': None, 'Aerosmith': None, 'Agent Orange': None, 'Agnostic Front': None, 'Ahmad Jamal': None, 'Aimee Mann': None, 'Air': None, 'Air Supply': None, 'Akon': None, 'Al B. Sure!': None, 'Al Bowlly': None, 'Al Cohn': None, 'Al Di Meola': None, 'Al Green': None, 'Al Jarreau': None, 'Al Kooper': None, 'Al Martino': None, 'Al Stewart': None, 'Alabama': None, 'Alan Jackson': None, 'Alan Lomax': None, 'Alan Parsons': None, 'Alanis Morissette': None, 'Albert Ayler': None, 'Albert Collins': None, 'Albert King': None, 'Alec Wilder': None, 'Alejandra GuzmÃ¡n': None, 'Alejandro Escovedo': None, 'Alejandro FernÃ¡ndez': None, 'Alejandro Sanz': None, 'Alex Van Halen': None, 'Alex de Grassi': None, "Alexander O'Neal": None, 'Alexandre Pires': None, 'Alfred Newman': None, 'Alfredo Gutierrez': None, 'Ali Akbar Khan': None, 'Ali Farka TourÃ©': None, 'Alice Coltrane': None, 'Alice Cooper': None, 'Alice in Chains': None, 'Alicia Keys': None, 'Alien Sex Fiend': None, 'Alison Krauss': None, 'Alkaline Trio': None, 'All': None, 'All That Remains': None, 'All Time Low': None, 'All-4-One': None, 'Alla Rakha': None, 'Allan Holdsworth': None, 'Allan Jones': None, 'Allan Sherman': None, 'Allen Toussaint': None, 'Alpha': None, 'Alpha Blondy': None, 'Alphaville': None, 'Alt-J': None, 'Altered Images': None, 'Alton Ellis': None, 'Alvin & the Chipmunks': None, 'Alvin Lee': None, 'Amel Larrieux': None, 'America': None, 'Amerie': None, 'Amos Milburn': None, 'Amy Grant': None, 'Amy Winehouse': None, 'AmÃ¡lia Rodrigues': None, 'Ana Gabriel': None, 'Anastacia': None, 'AndraÃ© Crouch': None, 'Andrea Bocelli': None, 'Andrew Bird': None, 'Andrew Hill': None, 'Andrew Lloyd Webber': None, 'AndrÃ© Kostelanetz': None, 'Andy Black': None, 'Andy Irvine': None, 'Andy Kim': None, 'Andy MontaÃ±ez': None, 'Andy Williams': None, 'Angel Witch': None, 'Angela Bofill': None, 'Angela Winbush': None, 'Angelic Upstarts': None, 'Angelo Badalamenti': None, 'Angels & Airwaves': None, 'Angie Stone': None, 'Ani DiFranco': None, 'Animal Collective': None, 'Anita Baker': None, 'Anita Bryant': None, "Anita O'Day": None, 'Ann Peebles': None, 'Anne Murray': None, 'Annette Peacock': None, 'Annie Lennox': None, 'Annie Ross': None, 'Annihilator': None, 'Another Bad Creation': None, 'Anthony Hamilton': None, 'Anthony Newley': None, 'Anthrax': None, 'Anti-Flag': None, 'Anti-Nowhere League': None, 'Antonio Aguilar': None, 'Antonio MachÃ\xadn': None, 'AntÃ´nio Carlos Jobim': None, 'Anvil': None, 'Aphex Twin': None, 'April March': None, 'Arcade Fire': None, 'Archers of Loaf': None, 'Archie Bell & the Drells': None, 'Archie Shepp': None, 'Arctic Monkeys': None, 'Aretha Franklin': None, 'Argent': None, 'Arif Mardin': None, 'Arlo Guthrie': None, 'Armand Van Helden': None, 'Armin van Buuren': None, 'Arrow': None, 'Art Blakey': None, 'Art Farmer': None, 'Art Garfunkel': None, 'Art Pepper': None, 'Arthur Conley': None, 'Arthur Lyman': None, 'Arthur Russell': None, 'Artie Shaw': None, 'Arvo PÃ¤rt': None, 'Ash': None, 'Asha Bhosle': None, 'Ashanti': None, 'Ashford & Simpson': None, 'Ashlee Simpson': None, 'Ashley Tisdale': None, 'Asia': None, 'Asleep at  ...

# %% [markdown]
# https://towardsdatascience.com/introduction-to-graph-algorithm-breadth-first-search-algorithm-in-python-8644b6d31880

# %%
# mencari jalur diantara 2 titik dalam grafik menggunakan BFS
def bfs_algo(graph, start, goal):
    # validasi dan hentikan program ketika 
    # tujuan awal sama dengan tujuan akhir
    if start == goal: 
        return "Tidak dapat melanjutkan, Tujuan anda sama dengan posisi anda saat ini!"
    # variabel kosong untuk melacak 
    # titik yang sudah pernah dikunjungi
    visited = []
    # variabel yang berisikan data titik awal
    # untuk melacak semua jalur yang akan diperiksa
    queue = [[start]]
    # terus melakukan perulangan sampai 
    # semua jalur yang memungkinkan telah diperiksa 
    while queue:
        # hapus jalur pertama dari antrian dan,
        # dapatkan titik terakhir dari jalur
        path = queue.pop(0)
        node = path[-1]
        # validasi apakah jalur terakhir dari antrian
        # sudah pernah dikunjungi sebelumnya
        if node not in visited:
            neighbours = graph[node]
            # Telusuri semua titik dari grafik yang belum dikunjungi,  
            # buat jalur baru dan masukkan dalam antrian 
            for neighbour in neighbours:
                new_path = list(path)
                new_path.append(neighbour)
                queue.append(new_path)
                # tampilkan jalur antara titik awal hingga akhir
                # ketika titik saat ini adalah tujuan akhir
                if neighbour == goal:
                    return new_path
            # tandai titik sudah dikunjungi
            visited.append(node)
    # hentikan program ketika jalur (awal, akhir) yang diberikan 
    # tidak terdaftar didalam daftar sambungan
    return "Jalur tidak ditemukan, pastikan memasukkan data dengan tepat sesuai daftar"

# %% [markdown]
# https://github.com/bakode/bfs_algo/blob/master/search_algorithm_bfs.ipynb

# %%
graph_edges = {
    'Yogyakarta': ['Bantul','GunungKidul', 'Wates', 'Magelang', 'Klaten'],
    'Wates': ['Bantul','Yogyakarta','Magelang','Purworejo','Wonosobo'],
    'Bantul': ['Wates', 'Yogyakarta', 'GunungKidul'],
    'GunungKidul': ['Bantul','Yogyakarta','Klaten','Pacitan'],
    'Klaten': ['Salatiga','Yogyakarta','GunungKidul','Solo'],
    'Magelang': ['Wonosobo','Yogyakarta','Wates','Semarang','Salatiga'],
    'Pacitan': ['GunungKidul','Solo'],
    'Purworejo': ['Wates','Wonosobo'],
    'Wonosobo': ['Wates','Magelang'],
    'Semarang': ['Salatiga','Magelang'],
    'Salatiga': ['Magelang','Klaten','Solo'],
    'Solo': ['Salatiga','Klaten','Pacitan'],
}

# %%
bfs_algo(graph_edges, "Yogyakarta", "Salatiga")
# Out:
# ['Yogyakarta', 'Magelang', 'Salatiga']

# %% [markdown]
# https://github.com/tsengchan/GraphAlgoBFS/blob/master/GraphBFSalgo.ipynb

# %% [markdown]
# https://github.com/TAJWAR99/Python_Algorithms/blob/main/bfs_Algo.ipynb

# %% [markdown]
# https://github.com/TAJWAR99/Python_Algorithms/blob/main/bfs_Algo.ipynb

# %%
graph = {
  '5' : ['3','7'],
  '3' : ['2', '4'],
  '7' : ['8'],
  '2' : [],
  '4' : ['8'],
  '8' : []
}

visited = [] # List for visited nodes.
queue = []     #Initialize a queue

def bfs(visited, graph, node): #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0) 
    print (m, end = " ") 

    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

# Driver Code
print("Following is the Breadth-First Search")
bfs(visited, graph_edges, 'Wates')    # function calling
# Out:
# Following is the Breadth-First Search
# Wates Bantul Yogyakarta Magelang Purworejo Wonosobo GunungKidul Klaten Semarang Salatiga Pacitan Solo

# %% [markdown]
# https://github.com/tsengchan/GraphAlgoBFS/blob/master/GraphBFSalgo.ipynb

# %%
from collections import deque
import networkx as nx
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt


inf = float('inf')

attrs1 = {'V':{'color': 'white', 'distance': inf,'parent': 'nothing'},
         'R': {'color': 'white', 'distance': inf,'parent': 'nothing'},
         'S': {'color': 'white', 'distance': inf,'parent': 'nothing'},
         'W': {'color': 'white', 'distance': inf,'parent': 'nothing'},
         'T': {'color': 'white', 'distance': inf,'parent': 'nothing'},
         'X': {'color': 'white', 'distance': inf,'parent': 'nothing'},
         'U': {'color': 'white', 'distance': inf,'parent': 'nothing'},
         'Y': {'color': 'white', 'distance': inf,'parent': 'nothing'}        
        }

G1 = nx.Graph(graph1)

nx.set_node_attributes(G1,attrs1)





def breadth(graph,start):

    graph.nodes[start]['color']='gray'
    graph.nodes[start]['distance']=0
    graph.nodes[start]['parent']=None

    enqueue = deque(start)
    while enqueue: 
        u = enqueue.pop()
        print("u: %s" %u)
        
        
        for index,v in enumerate(nx.all_neighbors(graph,u)):

            print("v: %s" %v)
            if graph.nodes[v]['color']=='white':
                
                graph.nodes[v]['color']='gray'
                graph.nodes[v]['distance']=graph.nodes[u]['distance']+1
                print("node %s color %s" %(v,graph.nodes[v]['color']) ) 


                enqueue.appendleft(v)
                

           
            
            graph.nodes[u]['color']='black'
            print("stop")
                

    
    return graph

# %%
figure(num=None, figsize=(14, 12), dpi=80, facecolor='w', edgecolor='k')
nx.draw_networkx(G1)

plt.savefig("GraphBFS.png")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# https://github.com/chatmethar-comp/searchBFS_DFS

# %%
visited = []
queue = []
def bfs(visited, graph, node):
  visited.append(node)
  queue.append(node)
  while queue:
    s = queue.pop(0)
    # print(s,end="\n")
    for neighbour in graph[s]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)
        print('neighbour :',neighbour)
        print('visited:',visited)
    print('neighbour queue:',queue)

bfs(visited, data, 'Erasure')
# Out:
# neighbour : Cut Copy
# visited: ['Erasure', 'Cut Copy']
# neighbour : Felix da Housecat
# visited: ['Erasure', 'Cut Copy', 'Felix da Housecat']
# neighbour : Fischerspooner
# visited: ['Erasure', 'Cut Copy', 'Felix da Housecat', 'Fischerspooner']
# neighbour : Ladytron
# visited: ['Erasure', 'Cut Copy', 'Felix da Housecat', 'Fischerspooner', 'Ladytron']
# neighbour : Savage Garden
# visited: ['Erasure', 'Cut Copy', 'Felix da Housecat', 'Fischerspooner', 'Ladytron', 'Savage Garden']
# neighbour : Kaskade
# visited: ['Erasure', 'Cut Copy', 'Felix da Housecat', 'Fischerspooner', 'Ladytron', 'Savage Garden', 'Kaskade']
# neighbour : The Postal Service
# visited: ['Erasure', 'Cut Copy', 'Felix da Housecat', 'Fischerspooner', 'Ladytron', 'Savage Garden', 'Kaskade', 'The Postal Service']
# neighbour : 808 State
# visited: ['Erasure', 'Cut Copy', 'Felix da Housecat', 'Fischerspooner', 'Ladytron', 'Savage Garden', 'Kaskade', 'The Postal Service', '808 State']
# neighbour : La Roux
# visited: ['Erasure', 'Cut Copy', 'Felix da Housecat', 'Fischerspooner', 'Ladytron', 'Savage Garden', 'Kaskade', 'The Postal Service', '808 State', 'La Roux']
# neighbour queue: ['Cut Copy', 'Felix da Housecat', 'Fischerspooner', 'Ladytron', 'Savage Garden', 'Kaskade', 'The Postal Service', '808 State', 'La Roux']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-0db3f1769c66> in <module>()
#      17     print('neighbour queue:',queue)
#      18
# ---> 19 bfs(visited, data, 'Erasure')
#      20
#
# <ipython-input-50-0db3f1769c66> in bfs(visited, graph, node)
#       9     s = queue.pop(0)
#      10     # print(s,end="\n")
# ---> 11     for neighbour in graph[s]:
#      12       if neighbour not in visited:
#      13         visited.append(neighbour)
#
# KeyError: 'Cut Copy'
